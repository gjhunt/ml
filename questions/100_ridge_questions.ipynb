# %% [markdown]
# # Ridge Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of penalized least squares on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For penalized least squares, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of the ridge objective on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For the ridge objective, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of closed-form ridge solution on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For closed-form ridge solution, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of why $X^TX+\lambda I$ is invertible on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For why $X^TX+\lambda I$ is invertible, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of coefficient shrinkage on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For coefficient shrinkage, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of bias-variance tradeoff on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For bias-variance tradeoff, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of standardization before penalties on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For standardization before penalties, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of intercepts and penalties on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For intercepts and penalties, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of SVD interpretation on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For SVD interpretation, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of filter factors on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For filter factors, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of multicollinearity on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For multicollinearity, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of effective degrees of freedom on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For effective degrees of freedom, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of limits as $\lambda\to0$ and $\lambda\to\infty$ on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For limits as $\lambda\to0$ and $\lambda\to\infty$, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of prediction stability on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For prediction stability, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of validation for lambda on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For validation for lambda, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of geometric penalty balls on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For geometric penalty balls, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of Bayesian Gaussian prior intuition on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For Bayesian Gaussian prior intuition, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of training versus test error on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For training versus test error, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of ridge with polynomial features on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For ridge with polynomial features, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Using the ridge objective $\|y-Xw\|^2+\lambda\|w\|_2^2$, derive or explain the effect of regularization on coefficients or predictions.
#
# <details>
# <summary>Answer</summary>
#
# For regularization, ridge minimizes $\|y-Xw\|^2+\lambda\|w\|_2^2$ with solution $(X^TX+\lambda I)^-1X^Ty$. The penalty shrinks unstable directions and trades bias for variance.
#
# </details>
