# %% [markdown]
# # Ridge Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Classify the following situation for penalized ERM: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Ridge Regression lecture; Conceptual classification; penalized ERM -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For penalized ERM, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Perturb one observation or one feature scale. Determine whether ridge objective changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Ridge Regression lecture; Sensitivity check; ridge objective -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For ridge objective, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# A student claims that closed-form ridge solution is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Ridge Regression lecture; False-claim diagnosis; closed-form ridge solution -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For closed-form ridge solution, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Take the relevant tuning parameter or sample size in invertibility of $X^TX+\lambda I$ to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Ridge Regression lecture; Boundary case; invertibility of $X^TX+\lambda I$ -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 5
#
# State the prediction or decision rule associated with coefficient shrinkage; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Ridge Regression lecture; Prediction rule; coefficient shrinkage -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For coefficient shrinkage, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of bias-variance tradeoff. Verify the example in one or two equations.
#
# <!-- Source: Ridge Regression lecture; Counterexample or edge case; bias-variance tradeoff -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For bias-variance tradeoff, use the lecture formulas to compute the relevant quantity before and after the assumption fails. Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Prove the easy implication involving standardization before penalties, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Ridge Regression lecture; One direction and converse; standardization before penalties -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For standardization before penalties, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Verify the monotonicity, convexity, or non-increase property asserted for intercept handling; state exactly what is monotone or convex.
#
# <!-- Source: Ridge Regression lecture; Property verification; intercept handling -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For intercept handling, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Compare SVD/eigen interpretation with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Ridge Regression lecture; Precise comparison; SVD/eigen interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For SVD/eigen interpretation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Express filter factors as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Ridge Regression lecture; ERM translation; filter factors -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For filter factors, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Design a compact diagnostic for detecting a problem with multicollinearity using only quantities introduced in the lecture.
#
# <!-- Source: Ridge Regression lecture; Diagnostic; multicollinearity -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For multicollinearity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# On a toy sample with two observations, compute the lecture quantity behind effective degrees of freedom; use symbols if the lecture did not give numbers.
#
# <!-- Source: Ridge Regression lecture; Small computation; effective degrees of freedom -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometry to describe limits as $\lambda\to0,\infty$ as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Ridge Regression lecture; Geometric interpretation; limits as $\lambda\to0,\infty$ -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Connect prediction stability to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Ridge Regression lecture; Concept bridge; prediction stability -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For prediction stability, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Identify the nontrivial assumption that makes the lecture statement about validation for $\lambda$ valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Ridge Regression lecture; Hypothesis check; validation for $\lambda$ -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 16
#
# For the algorithmic step involving penalty-ball geometry, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Ridge Regression lecture; Algorithm step; penalty-ball geometry -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For penalty-ball geometry, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Write the lecture formula for Gaussian-prior intuition. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Ridge Regression lecture; Formula check; Gaussian-prior intuition -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For Gaussian-prior intuition, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Rewrite training versus test error in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Ridge Regression lecture; Matrix notation and shape check; training versus test error -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For training versus test error, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Fill in the omitted algebraic step that connects ridge polynomial features to the next displayed formula in the lecture.
#
# <!-- Source: Ridge Regression lecture; Omitted algebra; ridge polynomial features -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For ridge polynomial features, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Derive the first-order condition or one-step update associated with regularization role, making clear which loss or objective is being differentiated.
#
# <!-- Source: Ridge Regression lecture; Gap-filling derivation; regularization role -->
#
# <details>
# <summary>Answer</summary>
#
# Ridge solves $(X^TX+\lambda I)\hat w=X^Ty$ and shrinks unstable directions. The eigenvalue view shows each principal direction is damped by a $\lambda$-dependent factor. For regularization role, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
