# %% [markdown]
# # Introduction to Statistical Machine Learning
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Why can a predictor with very small loss on the observed sample still fail to generalize to a new draw $(X,Y)\sim P_{X,Y}$?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# Training loss is computed on the observed sample, but learning targets new draws from $P_{X,Y}$. A rule can fit noise in the sample, so low empirical risk is only a proxy for low population risk.
#
# </details>

# %% [markdown]
# ### Question 2
#
# In the lecture notation, how do regression and classification differ in the codomain of $\hat f$, and why should this change the loss function?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# Regression has $y\in\mathbb R$ and real-valued predictions; classification has $y\in\{c_1,\ldots,c_K\}$. The loss should match the output space: squared error for real errors, classification or likelihood losses for categories.
#
# </details>

# %% [markdown]
# ### Question 3
#
# If only $x_1,\ldots,x_N$ are observed, what structure can an unsupervised method try to learn, and why is there no supervised target risk?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# Without labels there is no supervised target. The mathematical task is exploratory: find structure such as clusters, dependence, or low-dimensional summaries in the marginal distribution of $X$.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Give an example where a real-valued score $s(x)$ and an action $a(s)$ should be treated as separate objects.
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# A score $s(x)$ can be real-valued while the action maps it to a decision, such as $a(s)=1\{s>0\}$. Changing the action threshold can change classifications without refitting the score.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Write the population risk $R(s)$ for a score function $s$ and explain why it is the ideal learning target.
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# Population risk is $R(s)=\mathbb E[\ell(Y,s(X))]$. It averages loss over the data-generating distribution, so it is the ideal out-of-sample criterion.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Write the empirical risk $\hat R(s)$ and explain precisely what unknown quantity it approximates.
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# Empirical risk is $\hat R(s)=N^{-1}\sum_n \ell(y_n,s(x_n))$. It replaces an unknown expectation by a sample average and is therefore computable.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Prove that multiplying an empirical-risk objective by a positive constant does not change its minimizers.
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# If $c>0$, then $\arg\min_s c\hat R(s)=\arg\min_s\hat R(s)$ because multiplication by $c$ preserves all order comparisons.
#
# </details>

# %% [markdown]
# ### Question 8
#
# What does empirical zero-one loss estimate, and why is it usually hard to optimize directly?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# Zero-one loss estimates the probability of an incorrect action, but it is discontinuous and usually nonconvex in model parameters, making direct optimization difficult.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Where does the i.i.d. assumption enter the argument that empirical risk is a reasonable proxy for population risk?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# For fixed $s$, the losses are i.i.d. with mean $R(s)$. Laws of large numbers justify $\hat R(s)$ as an approximation to $R(s)$.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Why does the lecture describe statistical machine-learning models as approximations rather than exact descriptions of reality?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# The lecture’s statistical viewpoint treats data as noisy and incomplete. A model is useful if it predicts or summarizes well, not because it is literally true.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Why must ERM minimize over a restricted model class rather than over all possible functions?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# ERM is meaningful only after restricting the candidate functions. Too large a class can interpolate arbitrary training labels and generalize poorly.
#
# </details>

# %% [markdown]
# ### Question 12
#
# For squared-error regression with identity action, what is the relationship between the score $\hat s(x)$ and prediction $\hat f(x)$?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# For squared-error regression the action is often $a(s)=s$, so $\hat f(x)=\hat s(x)$. The score and prediction coincide.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Give a scenario in which two predictors tie on empirical risk but have different population risks.
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# Two functions may tie on empirical risk but differ off sample. This illustrates why evaluation, regularization, and assumptions are needed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# In the notation $\mathcal C=\{c_1,\ldots,c_K\}$, what makes a problem multi-class rather than binary?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# The predictor maps into a finite set $\mathcal C=\{c_1,\ldots,c_K\}$. Multi-class classification is the case $K>2$.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Why should the loss function encode the scientific or decision-making goal of the learning problem?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# The learned rule optimizes the chosen loss. If the loss does not encode the scientific or decision goal, ERM can solve the wrong problem perfectly.
#
# </details>

# %% [markdown]
# ### Question 16
#
# What does the lecture mean by performance on “new” or “unseen” data, mathematically?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# The phrase “new data” means another draw from the same distribution $P$, not merely another row already used for fitting.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Contrast the mathematical objectives of supervised and unsupervised learning using the presence or absence of $Y$.
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# Supervised learning estimates a relation between $X$ and $Y$; unsupervised learning studies structure in $X$ alone.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Name two sources of uncertainty in the statistical setup and explain how risk averages over them.
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# Randomness can represent measurement noise, unobserved variables, or inherent variability; risk averages over these sources.
#
# </details>

# %% [markdown]
# ### Question 19
#
# What are the two course questions “how do we construct $\hat f$?” and “how do we know it is good?” asking mathematically?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# Methods construct $\hat f$ from data; evaluation asks how good $\hat f$ is. The two interact but are logically distinct.
#
# </details>

# %% [markdown]
# ### Question 20
#
# How can ERM overfit when the model class is too flexible, even if the empirical risk is minimized exactly?
#
# <!-- Source: intro/statistical setup/ERM sections -->
#
# <details>
# <summary>Answer</summary>
#
# A highly flexible ERM can drive empirical risk down by matching accidental sample patterns, increasing population risk.
#
# </details>
