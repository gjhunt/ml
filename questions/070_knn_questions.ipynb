# %% [markdown]
# # K-Nearest Neighbors
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# A student claims that population risk framework is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: K-Nearest Neighbors lecture; False-claim diagnosis; population risk framework -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For population risk framework, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Take the relevant tuning parameter or sample size in pointwise optimization to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: K-Nearest Neighbors lecture; Boundary case; pointwise optimization -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 3
#
# State the prediction or decision rule associated with squared-loss regression target; include how ties or non-uniqueness should be handled.
#
# <!-- Source: K-Nearest Neighbors lecture; Prediction rule; squared-loss regression target -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For squared-loss regression target, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of statistical problem. Verify the example in one or two equations.
#
# <!-- Source: K-Nearest Neighbors lecture; Counterexample or edge case; statistical problem -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For statistical problem, use the lecture formulas to compute the relevant quantity before and after the assumption fails. KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Prove the easy implication involving local approximation principle, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: K-Nearest Neighbors lecture; One direction and converse; local approximation principle -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For local approximation principle, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Verify the monotonicity, convexity, or non-increase property asserted for KNN regression average; state exactly what is monotone or convex.
#
# <!-- Source: K-Nearest Neighbors lecture; Property verification; KNN regression average -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For KNN regression average, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Compare comparison to linear regression with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: K-Nearest Neighbors lecture; Precise comparison; comparison to linear regression -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For comparison to linear regression, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Express tuning $k$ as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: K-Nearest Neighbors lecture; ERM translation; tuning $k$ -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For tuning $k$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Design a compact diagnostic for detecting a problem with nested CV for $k$ using only quantities introduced in the lecture.
#
# <!-- Source: K-Nearest Neighbors lecture; Diagnostic; nested CV for $k$ -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For nested CV for $k$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# On a toy sample with two observations, compute the lecture quantity behind penguins distance behavior; use symbols if the lecture did not give numbers.
#
# <!-- Source: K-Nearest Neighbors lecture; Small computation; penguins distance behavior -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Use the lecture geometry to describe 0-1 loss as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: K-Nearest Neighbors lecture; Geometric interpretation; 0-1 loss -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Connect KNN classification vote to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: K-Nearest Neighbors lecture; Concept bridge; KNN classification vote -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For KNN classification vote, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Identify the nontrivial assumption that makes the lecture statement about comparison to logistic regression valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: K-Nearest Neighbors lecture; Hypothesis check; comparison to logistic regression -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 14
#
# For the algorithmic step involving distance metric, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: K-Nearest Neighbors lecture; Algorithm step; distance metric -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For distance metric, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Write the lecture formula for feature scaling. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: K-Nearest Neighbors lecture; Formula check; feature scaling -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For feature scaling, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Rewrite ties in voting in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: K-Nearest Neighbors lecture; Matrix notation and shape check; ties in voting -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For ties in voting, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Fill in the omitted algebraic step that connects large-$k$ smoothing to the next displayed formula in the lecture.
#
# <!-- Source: K-Nearest Neighbors lecture; Omitted algebra; large-$k$ smoothing -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For large-$k$ smoothing, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Derive the first-order condition or one-step update associated with small-$k$ variance, making clear which loss or objective is being differentiated.
#
# <!-- Source: K-Nearest Neighbors lecture; Gap-filling derivation; small-$k$ variance -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For small-$k$ variance, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Classify the following situation for MNIST high-dimensional inputs: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: K-Nearest Neighbors lecture; Conceptual classification; MNIST high-dimensional inputs -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For MNIST high-dimensional inputs, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Perturb one observation or one feature scale. Determine whether limitations of KNN changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: K-Nearest Neighbors lecture; Sensitivity check; limitations of KNN -->
#
# <details>
# <summary>Answer</summary>
#
# KNN predicts from the $k$ nearest training inputs under a chosen metric: averages for regression and votes for classification. The mathematical tradeoff is locality versus variance, controlled by $k$, scaling, and dimension. For limitations of KNN, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
