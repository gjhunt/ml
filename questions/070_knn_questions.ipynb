# %% [markdown]
# # K-Nearest Neighbors
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# For KNN, how does population nearest-neighbor intuition affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses population nearest-neighbor intuition as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 2
#
# For KNN, how does the distance metric affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses the distance metric as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 3
#
# For KNN, how does choosing $K$ affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses choosing $K$ as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 4
#
# For KNN, how does classification by majority vote affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses classification by majority vote as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 5
#
# For KNN, how does regression by local averaging affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses regression by local averaging as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For KNN, how does decision boundaries affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses decision boundaries as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 7
#
# For KNN, how does feature scaling affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses feature scaling as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 8
#
# For KNN, how does bias-variance tradeoff in $K$ affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses bias-variance tradeoff in $K$ as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 9
#
# For KNN, how does curse of dimensionality for neighbors affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses curse of dimensionality for neighbors as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 10
#
# For KNN, how does ties affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses ties as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 11
#
# For KNN, how does weighted neighbors affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses weighted neighbors as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 12
#
# For KNN, how does training cost versus prediction cost affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses training cost versus prediction cost as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 13
#
# For KNN, how does nonparametric model classes affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses nonparametric model classes as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 14
#
# For KNN, how does local constant approximation affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses local constant approximation as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 15
#
# For KNN, how does standardization affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses standardization as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 16
#
# For KNN, how does Voronoi cells for 1-NN affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses Voronoi cells for 1-NN as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 17
#
# For KNN, how does large-$K$ smoothing affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses large-$K$ smoothing as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 18
#
# For KNN, how does small-$K$ variance affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses small-$K$ variance as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 19
#
# For KNN, how does evaluation of KNN affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses evaluation of KNN as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>

# %% [markdown]
# ### Question 20
#
# For KNN, how does limitations affect the neighbor set, prediction rule, or bias-variance behavior? Give a mathematical or geometric explanation.
#
# <details>
# <summary>Answer</summary>
#
# The lecture uses limitations as a core mathematical point. The answer should connect the formal definition to the corresponding objective, algorithm, or geometric interpretation in the notebook.
#
# </details>
