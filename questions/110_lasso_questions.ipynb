# %% [markdown]
# # Lasso Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how the lasso objective affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how the lasso obje -->
#
# <details>
# <summary>Answer</summary>
#
# For the lasso objective, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how the $\ell_1$ penalty affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how the ell1 penal -->
#
# <details>
# <summary>Answer</summary>
#
# For the $\ell_1$ penalty, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how sparsity affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how sparsity affec -->
#
# <details>
# <summary>Answer</summary>
#
# For sparsity, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how soft-thresholding affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how soft-threshold -->
#
# <details>
# <summary>Answer</summary>
#
# For soft-thresholding, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how coordinate descent affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how coordinate des -->
#
# <details>
# <summary>Answer</summary>
#
# For coordinate descent, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how standardization affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how standardizatio -->
#
# <details>
# <summary>Answer</summary>
#
# For standardization, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how intercepts affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how intercepts aff -->
#
# <details>
# <summary>Answer</summary>
#
# For intercepts, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how non-differentiability at zero affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how non-differenti -->
#
# <details>
# <summary>Answer</summary>
#
# For non-differentiability at zero, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how subgradients affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how subgradients a -->
#
# <details>
# <summary>Answer</summary>
#
# For subgradients, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how geometric diamonds affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how geometric diam -->
#
# <details>
# <summary>Answer</summary>
#
# For geometric diamonds, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how feature selection affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how feature select -->
#
# <details>
# <summary>Answer</summary>
#
# For feature selection, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how correlated predictors affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how correlated pre -->
#
# <details>
# <summary>Answer</summary>
#
# For correlated predictors, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how comparison with ridge affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how comparison wit -->
#
# <details>
# <summary>Answer</summary>
#
# For comparison with ridge, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how bias from shrinkage affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how bias from shri -->
#
# <details>
# <summary>Answer</summary>
#
# For bias from shrinkage, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how lambda paths affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how lambda paths a -->
#
# <details>
# <summary>Answer</summary>
#
# For lambda paths, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how validation affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how validation aff -->
#
# <details>
# <summary>Answer</summary>
#
# For validation, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how KKT conditions affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how KKT conditions -->
#
# <details>
# <summary>Answer</summary>
#
# For KKT conditions, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how least-angle intuition affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how least-angle in -->
#
# <details>
# <summary>Answer</summary>
#
# For least-angle intuition, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how high-dimensional settings affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how high-dimension -->
#
# <details>
# <summary>Answer</summary>
#
# For high-dimensional settings, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Using the lasso objective and the geometry of the $\ell_1$ penalty, explain how prediction versus interpretation affects sparsity, shrinkage, or coefficient selection.
#
# <!-- Source: Lasso Regression lecture; section related to: Using the lasso objective and the geometry of the ell1 penalty, explain how prediction ver -->
#
# <details>
# <summary>Answer</summary>
#
# For prediction versus interpretation, lasso minimizes squared error plus $\lambda\|w\|_1$. The nondifferentiable corner at zero creates subgradient conditions that can set coefficients exactly to zero, unlike ridge’s smooth shrinkage.
#
# </details>
