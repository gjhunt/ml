# %% [markdown]
# # Lasso Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Prove the easy implication involving LASSO objective, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Lasso Regression lecture; One direction and converse; LASSO objective -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For LASSO objective, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Verify the monotonicity, convexity, or non-increase property asserted for $\ell_1$ penalty; state exactly what is monotone or convex.
#
# <!-- Source: Lasso Regression lecture; Property verification; $\ell_1$ penalty -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For $\ell_1$ penalty, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Compare sparsity with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Lasso Regression lecture; Precise comparison; sparsity -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For sparsity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Express soft-thresholding as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Lasso Regression lecture; ERM translation; soft-thresholding -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For soft-thresholding, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Design a compact diagnostic for detecting a problem with coordinate descent using only quantities introduced in the lecture.
#
# <!-- Source: Lasso Regression lecture; Diagnostic; coordinate descent -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For coordinate descent, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# On a toy sample with two observations, compute the lecture quantity behind standardization; use symbols if the lecture did not give numbers.
#
# <!-- Source: Lasso Regression lecture; Small computation; standardization -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. Lasso adds $\lambda\|w\|_1$ to squared error. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Use the lecture geometry to describe intercept handling as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Lasso Regression lecture; Geometric interpretation; intercept handling -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Connect non-differentiability at zero to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Lasso Regression lecture; Concept bridge; non-differentiability at zero -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For non-differentiability at zero, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Identify the nontrivial assumption that makes the lecture statement about subgradients valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Lasso Regression lecture; Hypothesis check; subgradients -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. Lasso adds $\lambda\|w\|_1$ to squared error. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 10
#
# For the algorithmic step involving diamond geometry, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Lasso Regression lecture; Algorithm step; diamond geometry -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For diamond geometry, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Write the lecture formula for feature selection. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Lasso Regression lecture; Formula check; feature selection -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For feature selection, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Rewrite correlated predictors in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Lasso Regression lecture; Matrix notation and shape check; correlated predictors -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For correlated predictors, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Fill in the omitted algebraic step that connects comparison with ridge to the next displayed formula in the lecture.
#
# <!-- Source: Lasso Regression lecture; Omitted algebra; comparison with ridge -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For comparison with ridge, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Derive the first-order condition or one-step update associated with shrinkage bias, making clear which loss or objective is being differentiated.
#
# <!-- Source: Lasso Regression lecture; Gap-filling derivation; shrinkage bias -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For shrinkage bias, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Classify the following situation for lambda paths: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Lasso Regression lecture; Conceptual classification; lambda paths -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For lambda paths, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Perturb one observation or one feature scale. Determine whether validation for lambda changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Lasso Regression lecture; Sensitivity check; validation for lambda -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For validation for lambda, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# A student claims that KKT conditions is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Lasso Regression lecture; False-claim diagnosis; KKT conditions -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For KKT conditions, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Take the relevant tuning parameter or sample size in least-angle intuition to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Lasso Regression lecture; Boundary case; least-angle intuition -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. Lasso adds $\lambda\|w\|_1$ to squared error. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 19
#
# State the prediction or decision rule associated with high-dimensional case; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Lasso Regression lecture; Prediction rule; high-dimensional case -->
#
# <details>
# <summary>Answer</summary>
#
# Lasso adds $\lambda\|w\|_1$ to squared error. The subgradient interval at zero and the diamond geometry create exact sparsity, unlike ridge. For high-dimensional case, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of prediction versus interpretation. Verify the example in one or two equations.
#
# <!-- Source: Lasso Regression lecture; Counterexample or edge case; prediction versus interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For prediction versus interpretation, use the lecture formulas to compute the relevant quantity before and after the assumption fails. Lasso adds $\lambda\|w\|_1$ to squared error. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>
