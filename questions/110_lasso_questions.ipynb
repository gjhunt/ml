# %% [markdown]
# # Lasso Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for LASSO objective and identify how it enters the objective or prediction rule.
#
# <!-- Source: Lasso Regression lecture; LASSO objective -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for $\ell_1$ penalty, stating all assumptions.
#
# <!-- Source: Lasso Regression lecture; $\ell_1$ penalty -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about sparsity: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Lasso Regression lecture; sparsity -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with soft-thresholding when the relevant lecture assumption is removed.
#
# <!-- Source: Lasso Regression lecture; soft-thresholding -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely coordinate descent with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Lasso Regression lecture; coordinate descent -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for standardization and interpret the sign or magnitude.
#
# <!-- Source: Lasso Regression lecture; standardization -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make intercept handling well-defined.
#
# <!-- Source: Lasso Regression lecture; intercept handling -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for non-differentiability at zero in matrix notation and name each term.
#
# <!-- Source: Lasso Regression lecture; non-differentiability at zero -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about subgradients; justify the decision with a formula.
#
# <!-- Source: Lasso Regression lecture; subgradients -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for diamond geometry under the relevant tuning parameter.
#
# <!-- Source: Lasso Regression lecture; diamond geometry -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of feature selection in the lecture's model class.
#
# <!-- Source: Lasso Regression lecture; feature selection -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely correlated predictors into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Lasso Regression lecture; correlated predictors -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize comparison with ridge as a projection, partition, or transformation.
#
# <!-- Source: Lasso Regression lecture; comparison with ridge -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining shrinkage bias and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Lasso Regression lecture; shrinkage bias -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving lambda paths; which one fails in the common edge case?
#
# <!-- Source: Lasso Regression lecture; lambda paths -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how validation for lambda changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Lasso Regression lecture; validation for lambda -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with KKT conditions and resolve ties if needed.
#
# <!-- Source: Lasso Regression lecture; KKT conditions -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for least-angle intuition.
#
# <!-- Source: Lasso Regression lecture; least-angle intuition -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for high-dimensional case using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Lasso Regression lecture; high-dimensional case -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize prediction versus interpretation by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Lasso Regression lecture; prediction versus interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is lasso minimizes $\|y-Xw\|^2+\lambda\|w\|_1$. The subgradient condition at zero can be satisfied over an interval, producing exact zeros; with orthonormal predictors this becomes soft-thresholding.
#
# </details>
