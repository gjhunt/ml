# %% [markdown]
# # CART: Classification and Regression Trees
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# For CART, formulate how recursive splitting is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how recursive splitting is used to choose a split or assign a leaf pre -->
#
# <details>
# <summary>Answer</summary>
#
# For recursive splitting, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 2
#
# For CART, formulate how leaf regions is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how leaf regions is used to choose a split or assign a leaf prediction -->
#
# <details>
# <summary>Answer</summary>
#
# For leaf regions, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 3
#
# For CART, formulate how piecewise-constant prediction is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how piecewise-constant prediction is used to choose a split or assign  -->
#
# <details>
# <summary>Answer</summary>
#
# For piecewise-constant prediction, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 4
#
# For CART, formulate how regression tree leaf means is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how regression tree leaf means is used to choose a split or assign a l -->
#
# <details>
# <summary>Answer</summary>
#
# For regression tree leaf means, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 5
#
# For CART, formulate how by-hand split criteria is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how by-hand split criteria is used to choose a split or assign a leaf  -->
#
# <details>
# <summary>Answer</summary>
#
# For by-hand split criteria, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For CART, formulate how tree depth is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how tree depth is used to choose a split or assign a leaf prediction. -->
#
# <details>
# <summary>Answer</summary>
#
# For tree depth, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 7
#
# For CART, formulate how classification trees is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how classification trees is used to choose a split or assign a leaf pr -->
#
# <details>
# <summary>Answer</summary>
#
# For classification trees, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 8
#
# For CART, formulate how impurity measures is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how impurity measures is used to choose a split or assign a leaf predi -->
#
# <details>
# <summary>Answer</summary>
#
# For impurity measures, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 9
#
# For CART, formulate how Gini impurity is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how Gini impurity is used to choose a split or assign a leaf predictio -->
#
# <details>
# <summary>Answer</summary>
#
# For Gini impurity, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 10
#
# For CART, formulate how entropy impurity is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how entropy impurity is used to choose a split or assign a leaf predic -->
#
# <details>
# <summary>Answer</summary>
#
# For entropy impurity, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 11
#
# For CART, formulate how choosing classification splits is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how choosing classification splits is used to choose a split or assign -->
#
# <details>
# <summary>Answer</summary>
#
# For choosing classification splits, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 12
#
# For CART, formulate how axis-aligned rectangles is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how axis-aligned rectangles is used to choose a split or assign a leaf -->
#
# <details>
# <summary>Answer</summary>
#
# For axis-aligned rectangles, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 13
#
# For CART, formulate how diabetes data is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how diabetes data is used to choose a split or assign a leaf predictio -->
#
# <details>
# <summary>Answer</summary>
#
# For diabetes data, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 14
#
# For CART, formulate how breast cancer classification is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how breast cancer classification is used to choose a split or assign a -->
#
# <details>
# <summary>Answer</summary>
#
# For breast cancer classification, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 15
#
# For CART, formulate how scaling invariance is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how scaling invariance is used to choose a split or assign a leaf pred -->
#
# <details>
# <summary>Answer</summary>
#
# For scaling invariance, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 16
#
# For CART, formulate how categorical variables is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how categorical variables is used to choose a split or assign a leaf p -->
#
# <details>
# <summary>Answer</summary>
#
# For categorical variables, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 17
#
# For CART, formulate how missing values is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how missing values is used to choose a split or assign a leaf predicti -->
#
# <details>
# <summary>Answer</summary>
#
# For missing values, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 18
#
# For CART, formulate how interpretation is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how interpretation is used to choose a split or assign a leaf predicti -->
#
# <details>
# <summary>Answer</summary>
#
# For interpretation, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 19
#
# For CART, formulate how overfitting deep trees is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how overfitting deep trees is used to choose a split or assign a leaf  -->
#
# <details>
# <summary>Answer</summary>
#
# For overfitting deep trees, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>

# %% [markdown]
# ### Question 20
#
# For CART, formulate how pruning intuition is used to choose a split or assign a leaf prediction.
#
# <!-- Source: CART: Classification and Regression Trees lecture; section related to: For CART, formulate how pruning intuition is used to choose a split or assign a leaf predi -->
#
# <details>
# <summary>Answer</summary>
#
# For pruning intuition, a tree recursively partitions feature space by axis-aligned splits and predicts a constant in each leaf. Regression splits reduce squared error; classification splits reduce impurity such as Gini or entropy.
#
# </details>
