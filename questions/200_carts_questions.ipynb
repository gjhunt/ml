# %% [markdown]
# # CART: Classification and Regression Trees
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for recursive splitting and identify how it enters the objective or prediction rule.
#
# <!-- Source: CART: Classification and Regression Trees lecture; recursive splitting -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for leaf regions $R_m$, stating all assumptions.
#
# <!-- Source: CART: Classification and Regression Trees lecture; leaf regions $R_m$ -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about piecewise-constant prediction: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: CART: Classification and Regression Trees lecture; piecewise-constant prediction -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with regression leaf means when the relevant lecture assumption is removed.
#
# <!-- Source: CART: Classification and Regression Trees lecture; regression leaf means -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely by-hand split criterion with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: CART: Classification and Regression Trees lecture; by-hand split criterion -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for tree depth and interpret the sign or magnitude.
#
# <!-- Source: CART: Classification and Regression Trees lecture; tree depth -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make classification-tree prediction well-defined.
#
# <!-- Source: CART: Classification and Regression Trees lecture; classification-tree prediction -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for Gini impurity in matrix notation and name each term.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Gini impurity -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about entropy impurity; justify the decision with a formula.
#
# <!-- Source: CART: Classification and Regression Trees lecture; entropy impurity -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for classification split choice under the relevant tuning parameter.
#
# <!-- Source: CART: Classification and Regression Trees lecture; classification split choice -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of axis-aligned rectangles in the lecture's model class.
#
# <!-- Source: CART: Classification and Regression Trees lecture; axis-aligned rectangles -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely diabetes regression tree into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: CART: Classification and Regression Trees lecture; diabetes regression tree -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize breast-cancer classification tree as a projection, partition, or transformation.
#
# <!-- Source: CART: Classification and Regression Trees lecture; breast-cancer classification tree -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining scaling invariance and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: CART: Classification and Regression Trees lecture; scaling invariance -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving categorical variables; which one fails in the common edge case?
#
# <!-- Source: CART: Classification and Regression Trees lecture; categorical variables -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how missing values changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: CART: Classification and Regression Trees lecture; missing values -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with interpretation and resolve ties if needed.
#
# <!-- Source: CART: Classification and Regression Trees lecture; interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for overfitting deep trees.
#
# <!-- Source: CART: Classification and Regression Trees lecture; overfitting deep trees -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for pruning intuition using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: CART: Classification and Regression Trees lecture; pruning intuition -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize extrapolation limits by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: CART: Classification and Regression Trees lecture; extrapolation limits -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is CART recursively chooses axis-aligned splits to reduce squared error for regression or impurity for classification. Leaves predict means or majority/probability summaries within regions $R_m$.
#
# </details>
