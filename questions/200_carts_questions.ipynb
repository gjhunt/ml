# %% [markdown]
# # CART: Classification and Regression Trees
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Rewrite recursive splitting in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Matrix notation and shape check; recursive splitting -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For recursive splitting, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Fill in the omitted algebraic step that connects leaf regions $R_m$ to the next displayed formula in the lecture.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Omitted algebra; leaf regions $R_m$ -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For leaf regions $R_m$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Derive the first-order condition or one-step update associated with piecewise-constant prediction, making clear which loss or objective is being differentiated.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Gap-filling derivation; piecewise-constant prediction -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For piecewise-constant prediction, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Classify the following situation for regression leaf means: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Conceptual classification; regression leaf means -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For regression leaf means, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Perturb one observation or one feature scale. Determine whether by-hand split criterion changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Sensitivity check; by-hand split criterion -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For by-hand split criterion, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# A student claims that tree depth is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: CART: Classification and Regression Trees lecture; False-claim diagnosis; tree depth -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For tree depth, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Take the relevant tuning parameter or sample size in classification-tree prediction to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Boundary case; classification-tree prediction -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 8
#
# State the prediction or decision rule associated with Gini impurity; include how ties or non-uniqueness should be handled.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Prediction rule; Gini impurity -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For Gini impurity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of entropy impurity. Verify the example in one or two equations.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Counterexample or edge case; entropy impurity -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For entropy impurity, use the lecture formulas to compute the relevant quantity before and after the assumption fails. CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Prove the easy implication involving classification split choice, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: CART: Classification and Regression Trees lecture; One direction and converse; classification split choice -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For classification split choice, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Verify the monotonicity, convexity, or non-increase property asserted for axis-aligned rectangles; state exactly what is monotone or convex.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Property verification; axis-aligned rectangles -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For axis-aligned rectangles, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Compare diabetes regression tree with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Precise comparison; diabetes regression tree -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For diabetes regression tree, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Express breast-cancer classification tree as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: CART: Classification and Regression Trees lecture; ERM translation; breast-cancer classification tree -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For breast-cancer classification tree, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Design a compact diagnostic for detecting a problem with scaling invariance using only quantities introduced in the lecture.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Diagnostic; scaling invariance -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For scaling invariance, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# On a toy sample with two observations, compute the lecture quantity behind categorical variables; use symbols if the lecture did not give numbers.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Small computation; categorical variables -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Use the lecture geometry to describe missing values as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Geometric interpretation; missing values -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Connect interpretation to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Concept bridge; interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For interpretation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Identify the nontrivial assumption that makes the lecture statement about overfitting deep trees valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Hypothesis check; overfitting deep trees -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 19
#
# For the algorithmic step involving pruning intuition, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Algorithm step; pruning intuition -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For pruning intuition, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Write the lecture formula for extrapolation limits. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: CART: Classification and Regression Trees lecture; Formula check; extrapolation limits -->
#
# <details>
# <summary>Answer</summary>
#
# CART recursively partitions feature space into regions $R_m$ and predicts constants in leaves. Splits reduce squared error in regression or impurity such as Gini/entropy in classification. For extrapolation limits, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
