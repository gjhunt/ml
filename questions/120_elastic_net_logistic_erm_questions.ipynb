# %% [markdown]
# # Elastic Net, Logistic Regularization, and ERM
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for elastic-net objective and identify how it enters the objective or prediction rule.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; elastic-net objective -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for mixing $\ell_1$ and $\ell_2$, stating all assumptions.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; mixing $\ell_1$ and $\ell_2$ -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about ridge-versus-lasso behavior: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; ridge-versus-lasso behavior -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with correlated groups when the relevant lecture assumption is removed.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; correlated groups -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely coordinate descent update with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; coordinate descent update -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for tuning elastic net and interpret the sign or magnitude.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; tuning elastic net -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make logistic regression as ERM well-defined.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; logistic regression as ERM -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for penalized logistic objective in matrix notation and name each term.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; penalized logistic objective -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about intercept under penalties; justify the decision with a formula.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; intercept under penalties -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for standardization under the relevant tuning parameter.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; standardization -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of convexity in the lecture's model class.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; convexity -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely sparsity with stability into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; sparsity with stability -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize classification loss as a projection, partition, or transformation.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; classification loss -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining separable logistic data and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; separable logistic data -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving regularization paths; which one fails in the common edge case?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; regularization paths -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how hyperparameter selection changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; hyperparameter selection -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with objective scaling and resolve ties if needed.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; objective scaling -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for penalty geometry.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; penalty geometry -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for bias from penalties using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; bias from penalties -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize coefficient-path interpretation by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; coefficient-path interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is elastic net adds $\lambda[(1-\alpha)\|w\|_2^2/2+\alpha\|w\|_1]$ to an ERM loss. The $\ell_1$ part selects variables; the $\ell_2$ part stabilizes correlated groups.
#
# </details>
