# %% [markdown]
# # Elastic Net, Logistic Regularization, and ERM
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Connect elastic-net objective to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Concept bridge; elastic-net objective -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For elastic-net objective, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Identify the nontrivial assumption that makes the lecture statement about mixing $\ell_1$ and $\ell_2$ valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Hypothesis check; mixing $\ell_1$ and $\ell_2$ -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 3
#
# For the algorithmic step involving ridge-versus-lasso behavior, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Algorithm step; ridge-versus-lasso behavior -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For ridge-versus-lasso behavior, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Write the lecture formula for correlated groups. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Formula check; correlated groups -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For correlated groups, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Rewrite coordinate descent update in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Matrix notation and shape check; coordinate descent update -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For coordinate descent update, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Fill in the omitted algebraic step that connects tuning elastic net to the next displayed formula in the lecture.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Omitted algebra; tuning elastic net -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For tuning elastic net, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Derive the first-order condition or one-step update associated with logistic regression as ERM, making clear which loss or objective is being differentiated.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Gap-filling derivation; logistic regression as ERM -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For logistic regression as ERM, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Classify the following situation for penalized logistic objective: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Conceptual classification; penalized logistic objective -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For penalized logistic objective, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Perturb one observation or one feature scale. Determine whether intercept under penalties changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Sensitivity check; intercept under penalties -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For intercept under penalties, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# A student claims that standardization is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; False-claim diagnosis; standardization -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For standardization, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Take the relevant tuning parameter or sample size in convexity to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Boundary case; convexity -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 12
#
# State the prediction or decision rule associated with sparsity with stability; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Prediction rule; sparsity with stability -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For sparsity with stability, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of classification loss. Verify the example in one or two equations.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Counterexample or edge case; classification loss -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For classification loss, use the lecture formulas to compute the relevant quantity before and after the assumption fails. elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Prove the easy implication involving separable logistic data, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; One direction and converse; separable logistic data -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For separable logistic data, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Verify the monotonicity, convexity, or non-increase property asserted for regularization paths; state exactly what is monotone or convex.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Property verification; regularization paths -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For regularization paths, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Compare hyperparameter selection with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Precise comparison; hyperparameter selection -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For hyperparameter selection, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Express objective scaling as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; ERM translation; objective scaling -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For objective scaling, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Design a compact diagnostic for detecting a problem with penalty geometry using only quantities introduced in the lecture.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Diagnostic; penalty geometry -->
#
# <details>
# <summary>Answer</summary>
#
# elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. For penalty geometry, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# On a toy sample with two observations, compute the lecture quantity behind bias from penalties; use symbols if the lecture did not give numbers.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Small computation; bias from penalties -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Use the lecture geometry to describe coefficient-path interpretation as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; Geometric interpretation; coefficient-path interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. elastic net combines $\ell_1$ selection with $\ell_2$ stabilization and can be added to logistic ERM. The mixing parameter controls the sparsity/stability balance, especially for correlated features. This supplies both the picture and the calculation behind it.
#
# </details>
