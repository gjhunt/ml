# %% [markdown]
# # Elastic Net, Logistic Regularization, and ERM
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# In penalized ERM, how does elastic net penalties change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does elastic net penalties change the optimization objective and the -->
#
# <details>
# <summary>Answer</summary>
#
# For elastic net penalties, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 2
#
# In penalized ERM, how does combining $\ell_1$ and $\ell_2$ change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does combining ell1 and ell2 change the optimization objective and t -->
#
# <details>
# <summary>Answer</summary>
#
# For combining $\ell_1$ and $\ell_2$, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 3
#
# In penalized ERM, how does ridge versus lasso behavior change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does ridge versus lasso behavior change the optimization objective a -->
#
# <details>
# <summary>Answer</summary>
#
# For ridge versus lasso behavior, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 4
#
# In penalized ERM, how does grouped correlated features change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does grouped correlated features change the optimization objective a -->
#
# <details>
# <summary>Answer</summary>
#
# For grouped correlated features, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 5
#
# In penalized ERM, how does regularized logistic regression change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does regularized logistic regression change the optimization objecti -->
#
# <details>
# <summary>Answer</summary>
#
# For regularized logistic regression, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 6
#
# In penalized ERM, how does penalized ERM change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does penalized ERM change the optimization objective and the resulti -->
#
# <details>
# <summary>Answer</summary>
#
# For penalized ERM, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 7
#
# In penalized ERM, how does intercepts under regularization change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does intercepts under regularization change the optimization objecti -->
#
# <details>
# <summary>Answer</summary>
#
# For intercepts under regularization, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 8
#
# In penalized ERM, how does standardization change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does standardization change the optimization objective and the resul -->
#
# <details>
# <summary>Answer</summary>
#
# For standardization, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 9
#
# In penalized ERM, how does lambda and mixing parameters change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does lambda and mixing parameters change the optimization objective  -->
#
# <details>
# <summary>Answer</summary>
#
# For lambda and mixing parameters, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 10
#
# In penalized ERM, how does convexity change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does convexity change the optimization objective and the resulting f -->
#
# <details>
# <summary>Answer</summary>
#
# For convexity, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 11
#
# In penalized ERM, how does sparsity with stability change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does sparsity with stability change the optimization objective and t -->
#
# <details>
# <summary>Answer</summary>
#
# For sparsity with stability, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 12
#
# In penalized ERM, how does classification losses change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does classification losses change the optimization objective and the -->
#
# <details>
# <summary>Answer</summary>
#
# For classification losses, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 13
#
# In penalized ERM, how does separable logistic data change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does separable logistic data change the optimization objective and t -->
#
# <details>
# <summary>Answer</summary>
#
# For separable logistic data, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 14
#
# In penalized ERM, how does regularization paths change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does regularization paths change the optimization objective and the  -->
#
# <details>
# <summary>Answer</summary>
#
# For regularization paths, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 15
#
# In penalized ERM, how does hyperparameter selection change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does hyperparameter selection change the optimization objective and  -->
#
# <details>
# <summary>Answer</summary>
#
# For hyperparameter selection, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 16
#
# In penalized ERM, how does objective scaling change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does objective scaling change the optimization objective and the res -->
#
# <details>
# <summary>Answer</summary>
#
# For objective scaling, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 17
#
# In penalized ERM, how does penalty geometry change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does penalty geometry change the optimization objective and the resu -->
#
# <details>
# <summary>Answer</summary>
#
# For penalty geometry, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 18
#
# In penalized ERM, how does bias from penalties change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does bias from penalties change the optimization objective and the r -->
#
# <details>
# <summary>Answer</summary>
#
# For bias from penalties, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 19
#
# In penalized ERM, how does prediction tradeoffs change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does prediction tradeoffs change the optimization objective and the  -->
#
# <details>
# <summary>Answer</summary>
#
# For prediction tradeoffs, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 20
#
# In penalized ERM, how does model interpretation change the optimization objective and the resulting fitted model?
#
# <!-- Source: Elastic Net, Logistic Regularization, and ERM lecture; section related to: In penalized ERM, how does model interpretation change the optimization objective and the  -->
#
# <details>
# <summary>Answer</summary>
#
# For model interpretation, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>
