# %% [markdown]
# # Boosting
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# For boosting, explain how boosted regression trees affect the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For boosted regression trees, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 2
#
# For boosting, explain how residual fitting affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For residual fitting, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 3
#
# For boosting, explain how learning rate $\nu$ affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For learning rate $\nu$, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 4
#
# For boosting, explain how number of trees $M$ affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For number of trees $M$, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 5
#
# For boosting, explain how weak learners affect the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For weak learners, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For boosting, explain how simulated example affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For simulated example, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 7
#
# For boosting, explain how manual boosting loop affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For manual boosting loop, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 8
#
# For boosting, explain how effect of learning rate affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For effect of learning rate, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 9
#
# For boosting, explain how gradient boosting affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For gradient boosting, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 10
#
# For boosting, explain how functional gradients affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For functional gradients, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 11
#
# For boosting, explain how pseudo-residuals affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For pseudo-residuals, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 12
#
# For boosting, explain how squared error as a special case affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For squared error as a special case, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 13
#
# For boosting, explain how binary classification boosting affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For binary classification boosting, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 14
#
# For boosting, explain how multiclass boosting affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For multiclass boosting, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 15
#
# For boosting, explain how regularization affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For regularization, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 16
#
# For boosting, explain how tree depth affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For tree depth, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 17
#
# For boosting, explain how minimum leaf size affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For minimum leaf size, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 18
#
# For boosting, explain how early stopping affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For early stopping, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 19
#
# For boosting, explain how extrapolation limits affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For extrapolation limits, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>

# %% [markdown]
# ### Question 20
#
# For boosting, explain how modern implementations affects the residual/pseudo-residual target or the additive update $s_m=s_{m-1}+\nu h_m$.
#
# <details>
# <summary>Answer</summary>
#
# For modern implementations, boosting builds an additive score $s_m=s_{m-1}+\nu h_m$. For squared error, $h_m$ fits residuals; more generally it approximates a negative functional gradient, with learning rate and tree complexity acting as regularization.
#
# </details>
