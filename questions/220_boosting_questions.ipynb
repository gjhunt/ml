# %% [markdown]
# # Boosting
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Compare boosted regression trees with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Boosting lecture; Precise comparison; boosted regression trees -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For boosted regression trees, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Express residual fitting as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Boosting lecture; ERM translation; residual fitting -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For residual fitting, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Design a compact diagnostic for detecting a problem with learning rate $\nu$ using only quantities introduced in the lecture.
#
# <!-- Source: Boosting lecture; Diagnostic; learning rate $\nu$ -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For learning rate $\nu$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# On a toy sample with two observations, compute the lecture quantity behind number of trees $M$; use symbols if the lecture did not give numbers.
#
# <!-- Source: Boosting lecture; Small computation; number of trees $M$ -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Use the lecture geometry to describe weak learners as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Boosting lecture; Geometric interpretation; weak learners -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Connect simulated residual example to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Boosting lecture; Concept bridge; simulated residual example -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For simulated residual example, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Identify the nontrivial assumption that makes the lecture statement about manual boosting loop valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Boosting lecture; Hypothesis check; manual boosting loop -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 8
#
# For the algorithmic step involving learning-rate effect, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Boosting lecture; Algorithm step; learning-rate effect -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For learning-rate effect, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Write the lecture formula for gradient boosting. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Boosting lecture; Formula check; gradient boosting -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For gradient boosting, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Rewrite functional gradient in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Boosting lecture; Matrix notation and shape check; functional gradient -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For functional gradient, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Fill in the omitted algebraic step that connects pseudo-residuals to the next displayed formula in the lecture.
#
# <!-- Source: Boosting lecture; Omitted algebra; pseudo-residuals -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For pseudo-residuals, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Derive the first-order condition or one-step update associated with squared-error special case, making clear which loss or objective is being differentiated.
#
# <!-- Source: Boosting lecture; Gap-filling derivation; squared-error special case -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For squared-error special case, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Classify the following situation for binary classification boosting: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Boosting lecture; Conceptual classification; binary classification boosting -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For binary classification boosting, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Perturb one observation or one feature scale. Determine whether multiclass boosting changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Boosting lecture; Sensitivity check; multiclass boosting -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For multiclass boosting, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# A student claims that regularization is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Boosting lecture; False-claim diagnosis; regularization -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For regularization, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Take the relevant tuning parameter or sample size in tree depth to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Boosting lecture; Boundary case; tree depth -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 17
#
# State the prediction or decision rule associated with minimum leaf size; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Boosting lecture; Prediction rule; minimum leaf size -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For minimum leaf size, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of subsampling. Verify the example in one or two equations.
#
# <!-- Source: Boosting lecture; Counterexample or edge case; subsampling -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For subsampling, use the lecture formulas to compute the relevant quantity before and after the assumption fails. Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Prove the easy implication involving early stopping, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Boosting lecture; One direction and converse; early stopping -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For early stopping, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Verify the monotonicity, convexity, or non-increase property asserted for extrapolation limits; state exactly what is monotone or convex.
#
# <!-- Source: Boosting lecture; Property verification; extrapolation limits -->
#
# <details>
# <summary>Answer</summary>
#
# Boosting builds $s_m=s_{m-1}+\nu h_m$; squared-error boosting fits residuals and gradient boosting fits negative loss gradients. Learning rate, number of trees, depth, leaf size, subsampling, and early stopping regularize the additive expansion. For extrapolation limits, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
