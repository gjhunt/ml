# %% [markdown]
# # Neural Networks
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# State the prediction or decision rule associated with affine layer plus activation; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Neural Networks lecture; Prediction rule; affine layer plus activation -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For affine layer plus activation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of feature learning. Verify the example in one or two equations.
#
# <!-- Source: Neural Networks lecture; Counterexample or edge case; feature learning -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For feature learning, use the lecture formulas to compute the relevant quantity before and after the assumption fails. A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Prove the easy implication involving network composition, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Neural Networks lecture; One direction and converse; network composition -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For network composition, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Verify the monotonicity, convexity, or non-increase property asserted for graph terminology; state exactly what is monotone or convex.
#
# <!-- Source: Neural Networks lecture; Property verification; graph terminology -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For graph terminology, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare one-hidden-layer network with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Neural Networks lecture; Precise comparison; one-hidden-layer network -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For one-hidden-layer network, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Express regression output as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Neural Networks lecture; ERM translation; regression output -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For regression output, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Design a compact diagnostic for detecting a problem with classification output using only quantities introduced in the lecture.
#
# <!-- Source: Neural Networks lecture; Diagnostic; classification output -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For classification output, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# On a toy sample with two observations, compute the lecture quantity behind squared-error loss; use symbols if the lecture did not give numbers.
#
# <!-- Source: Neural Networks lecture; Small computation; squared-error loss -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Use the lecture geometry to describe cross-entropy loss as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Neural Networks lecture; Geometric interpretation; cross-entropy loss -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Connect ERM objective to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Neural Networks lecture; Concept bridge; ERM objective -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For ERM objective, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Identify the nontrivial assumption that makes the lecture statement about matrix dimensions valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Neural Networks lecture; Hypothesis check; matrix dimensions -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 12
#
# For the algorithmic step involving activation nonlinearity, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Neural Networks lecture; Algorithm step; activation nonlinearity -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For activation nonlinearity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Write the lecture formula for linear activations collapse. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Neural Networks lecture; Formula check; linear activations collapse -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For linear activations collapse, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Rewrite hidden-unit parameters in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Neural Networks lecture; Matrix notation and shape check; hidden-unit parameters -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For hidden-unit parameters, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Fill in the omitted algebraic step that connects depth versus representation to the next displayed formula in the lecture.
#
# <!-- Source: Neural Networks lecture; Omitted algebra; depth versus representation -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For depth versus representation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Derive the first-order condition or one-step update associated with classification probabilities, making clear which loss or objective is being differentiated.
#
# <!-- Source: Neural Networks lecture; Gap-filling derivation; classification probabilities -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For classification probabilities, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Classify the following situation for regression scores: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Neural Networks lecture; Conceptual classification; regression scores -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For regression scores, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Perturb one observation or one feature scale. Determine whether nonconvexity changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Neural Networks lecture; Sensitivity check; nonconvexity -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For nonconvexity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# A student claims that overparameterized models is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Neural Networks lecture; False-claim diagnosis; overparameterized models -->
#
# <details>
# <summary>Answer</summary>
#
# A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Nonlinear activations prevent the network from collapsing to one affine map and enable feature learning. For overparameterized models, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Take the relevant tuning parameter or sample size in neural net versus linear model to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Neural Networks lecture; Boundary case; neural net versus linear model -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. A feed-forward layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>
