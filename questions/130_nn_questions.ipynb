# %% [markdown]
# # Neural Networks
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for affine layer plus activation and identify how it enters the objective or prediction rule.
#
# <!-- Source: Neural Networks lecture; affine layer plus activation -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for feature learning, stating all assumptions.
#
# <!-- Source: Neural Networks lecture; feature learning -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about network composition: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Neural Networks lecture; network composition -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with graph terminology when the relevant lecture assumption is removed.
#
# <!-- Source: Neural Networks lecture; graph terminology -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely one-hidden-layer network with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Neural Networks lecture; one-hidden-layer network -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for regression output and interpret the sign or magnitude.
#
# <!-- Source: Neural Networks lecture; regression output -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make classification output well-defined.
#
# <!-- Source: Neural Networks lecture; classification output -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for squared-error loss in matrix notation and name each term.
#
# <!-- Source: Neural Networks lecture; squared-error loss -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about cross-entropy loss; justify the decision with a formula.
#
# <!-- Source: Neural Networks lecture; cross-entropy loss -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for ERM objective under the relevant tuning parameter.
#
# <!-- Source: Neural Networks lecture; ERM objective -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of matrix dimensions in the lecture's model class.
#
# <!-- Source: Neural Networks lecture; matrix dimensions -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely activation nonlinearity into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Neural Networks lecture; activation nonlinearity -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize linear activations collapse as a projection, partition, or transformation.
#
# <!-- Source: Neural Networks lecture; linear activations collapse -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining hidden-unit parameters and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Neural Networks lecture; hidden-unit parameters -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving depth versus representation; which one fails in the common edge case?
#
# <!-- Source: Neural Networks lecture; depth versus representation -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how classification probabilities changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Neural Networks lecture; classification probabilities -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with regression scores and resolve ties if needed.
#
# <!-- Source: Neural Networks lecture; regression scores -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for nonconvexity.
#
# <!-- Source: Neural Networks lecture; nonconvexity -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for overparameterized models using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Neural Networks lecture; overparameterized models -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize neural net versus linear model by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Neural Networks lecture; neural net versus linear model -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is a layer has $h^{(\ell)}=\phi(W^{(\ell)}h^{(\ell-1)}+b^{(\ell)})$. Composing affine maps with nonlinear activations yields learned features; without nonlinearities the network collapses to one affine map.
#
# </details>
