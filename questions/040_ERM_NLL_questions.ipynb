# %% [markdown]
# # ERM, Maximum Likelihood, KL, and Cross Entropy
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Connect maximum likelihood to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Concept bridge; maximum likelihood -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For maximum likelihood, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Identify the nontrivial assumption that makes the lecture statement about monotone log transformations valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Hypothesis check; monotone log transformations -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 3
#
# For the algorithmic step involving negative log-likelihood loss, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Algorithm step; negative log-likelihood loss -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For negative log-likelihood loss, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Write the lecture formula for MLE as ERM. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Formula check; MLE as ERM -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For MLE as ERM, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Rewrite Gaussian linear regression model in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Matrix notation and shape check; Gaussian linear regression model -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For Gaussian linear regression model, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Fill in the omitted algebraic step that connects Bernoulli logistic model to the next displayed formula in the lecture.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Omitted algebra; Bernoulli logistic model -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For Bernoulli logistic model, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Derive the first-order condition or one-step update associated with surprisal, making clear which loss or objective is being differentiated.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Gap-filling derivation; surprisal -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For surprisal, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Classify the following situation for cross entropy: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Conceptual classification; cross entropy -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For cross entropy, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Perturb one observation or one feature scale. Determine whether KL divergence changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Sensitivity check; KL divergence -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For KL divergence, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# A student claims that identity $H(P,Q)=H(P)+D_{KL}(P\|Q)$ is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; False-claim diagnosis; identity $H(P,Q)=H(P)+D_{KL}(P\|Q)$ -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For identity $H(P,Q)=H(P)+D_{KL}(P\|Q)$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Take the relevant tuning parameter or sample size in model misspecification to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Boundary case; model misspecification -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 12
#
# State the prediction or decision rule associated with conditional versus joint modeling; include how ties or non-uniqueness should be handled.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Prediction rule; conditional versus joint modeling -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For conditional versus joint modeling, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of sample-average approximation. Verify the example in one or two equations.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Counterexample or edge case; sample-average approximation -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For sample-average approximation, use the lecture formulas to compute the relevant quantity before and after the assumption fails. Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Prove the easy implication involving zero model probability, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; One direction and converse; zero model probability -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For zero model probability, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Verify the monotonicity, convexity, or non-increase property asserted for log-base changes; state exactly what is monotone or convex.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Property verification; log-base changes -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For log-base changes, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Compare one-hot cross entropy with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Precise comparison; one-hot cross entropy -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For one-hot cross entropy, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Express expected NLL as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; ERM translation; expected NLL -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For expected NLL, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Design a compact diagnostic for detecting a problem with probabilistic prediction using only quantities introduced in the lecture.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Diagnostic; probabilistic prediction -->
#
# <details>
# <summary>Answer</summary>
#
# Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. For probabilistic prediction, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# On a toy sample with two observations, compute the lecture quantity behind argmax versus argmin; use symbols if the lecture did not give numbers.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Small computation; argmax versus argmin -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Use the lecture geometry to describe statistical meaning of ERM as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Geometric interpretation; statistical meaning of ERM -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. Maximizing likelihood is equivalent to minimizing $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, and $H(P,Q)=H(P)+D_{KL}(P\|Q)$ separates the fixed truth from model mismatch. This supplies both the picture and the calculation behind it.
#
# </details>
