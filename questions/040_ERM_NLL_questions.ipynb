# %% [markdown]
# # ERM, Maximum Likelihood, KL, and Cross Entropy
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Using the lecture's treatment of maximum likelihood, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For maximum likelihood, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Using the lecture's treatment of monotone log transformations, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For monotone log transformations, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Using the lecture's treatment of negative log-likelihood as a loss, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For negative log-likelihood as a loss, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Using the lecture's treatment of MLE as ERM, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For MLE as ERM, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Using the lecture's treatment of Gaussian linear regression, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For Gaussian linear regression, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Using the lecture's treatment of Bernoulli logistic regression, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For Bernoulli logistic regression, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Using the lecture's treatment of surprisal, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For surprisal, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Using the lecture's treatment of cross entropy, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For cross entropy, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Using the lecture's treatment of KL divergence, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For KL divergence, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Using the lecture's treatment of the identity $H(P,Q)=H(P)+D_{KL}(P\|Q)$, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For the identity $H(P,Q)=H(P)+D_{KL}(P\|Q)$, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Using the lecture's treatment of model misspecification, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For model misspecification, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Using the lecture's treatment of conditional versus joint modeling, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For conditional versus joint modeling, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Using the lecture's treatment of sample averages, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For sample averages, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Using the lecture's treatment of zero model probability, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For zero model probability, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Using the lecture's treatment of log base changes, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For log base changes, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Using the lecture's treatment of one-hot cross entropy, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For one-hot cross entropy, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Using the lecture's treatment of expected NLL, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For expected NLL, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Using the lecture's treatment of probabilistic prediction, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For probabilistic prediction, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Using the lecture's treatment of argmax versus argmin, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For argmax versus argmin, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Using the lecture's treatment of the statistical meaning of ERM, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For the statistical meaning of ERM, the lecture’s link is that likelihood fitting minimizes average negative log-likelihood. In expectation this is cross entropy, equal to entropy plus a KL term, so the best model is the closest distribution in KL when the model is misspecified.
#
# </details>
