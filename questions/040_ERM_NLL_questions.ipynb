# %% [markdown]
# # ERM, Maximum Likelihood, KL, and Cross Entropy
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for maximum likelihood and identify how it enters the objective or prediction rule.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; maximum likelihood -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for monotone log transformations, stating all assumptions.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; monotone log transformations -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about negative log-likelihood as a loss: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; negative log-likelihood as a loss -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with MLE as ERM when the relevant lecture assumption is removed.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; MLE as ERM -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely Gaussian linear regression with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Gaussian linear regression -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for Bernoulli logistic regression and interpret the sign or magnitude.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; Bernoulli logistic regression -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make surprisal well-defined.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; surprisal -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for cross entropy in matrix notation and name each term.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; cross entropy -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about KL divergence; justify the decision with a formula.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; KL divergence -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for identity $H(P,Q)=H(P)+D_{KL}(P\|Q)$ under the relevant tuning parameter.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; identity $H(P,Q)=H(P)+D_{KL}(P\|Q)$ -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of model misspecification in the lecture's model class.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; model misspecification -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely conditional versus joint modeling into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; conditional versus joint modeling -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize sample averages as a projection, partition, or transformation.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; sample averages -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining zero model probability and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; zero model probability -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving log base changes; which one fails in the common edge case?
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; log base changes -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how one-hot cross entropy changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; one-hot cross entropy -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with expected NLL and resolve ties if needed.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; expected NLL -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for probabilistic prediction.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; probabilistic prediction -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for argmax versus argmin using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; argmax versus argmin -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize statistical meaning of ERM by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: ERM, Maximum Likelihood, KL, and Cross Entropy lecture; statistical meaning of ERM -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is negative log-likelihood turns likelihood maximization into ERM: minimize $N^{-1}\sum_n -\log q_\theta(y_n\mid x_n)$. In expectation this is cross entropy, differing from KL by the fixed entropy of the truth.
#
# </details>
