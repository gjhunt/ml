# %% [markdown]
# # Model Evaluation
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# A student claims that target performance is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Model Evaluation lecture; False-claim diagnosis; target performance -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For target performance, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Take the relevant tuning parameter or sample size in test data to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Model Evaluation lecture; Boundary case; test data -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. The target is performance on fresh data, not on observations used to fit $\hat f$. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 3
#
# State the prediction or decision rule associated with training-data optimism; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Model Evaluation lecture; Prediction rule; training-data optimism -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For training-data optimism, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of overfitting. Verify the example in one or two equations.
#
# <!-- Source: Model Evaluation lecture; Counterexample or edge case; overfitting -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For overfitting, use the lecture formulas to compute the relevant quantity before and after the assumption fails. The target is performance on fresh data, not on observations used to fit $\hat f$. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Prove the easy implication involving model complexity, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Model Evaluation lecture; One direction and converse; model complexity -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For model complexity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Verify the monotonicity, convexity, or non-increase property asserted for Efron optimism theorem; state exactly what is monotone or convex.
#
# <!-- Source: Model Evaluation lecture; Property verification; Efron optimism theorem -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For Efron optimism theorem, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Compare linear-regression optimism example with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Model Evaluation lecture; Precise comparison; linear-regression optimism example -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For linear-regression optimism example, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Express simulation evidence as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Model Evaluation lecture; ERM translation; simulation evidence -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For simulation evidence, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Design a compact diagnostic for detecting a problem with held-out evaluation using only quantities introduced in the lecture.
#
# <!-- Source: Model Evaluation lecture; Diagnostic; held-out evaluation -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For held-out evaluation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# On a toy sample with two observations, compute the lecture quantity behind final model after evaluation; use symbols if the lecture did not give numbers.
#
# <!-- Source: Model Evaluation lecture; Small computation; final model after evaluation -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. The target is performance on fresh data, not on observations used to fit $\hat f$. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Use the lecture geometry to describe variance of evaluation estimates as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Model Evaluation lecture; Geometric interpretation; variance of evaluation estimates -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Connect data leakage to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Model Evaluation lecture; Concept bridge; data leakage -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For data leakage, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Identify the nontrivial assumption that makes the lecture statement about performance metrics valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Model Evaluation lecture; Hypothesis check; performance metrics -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. The target is performance on fresh data, not on observations used to fit $\hat f$. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 14
#
# For the algorithmic step involving classification accuracy, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Model Evaluation lecture; Algorithm step; classification accuracy -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For classification accuracy, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Write the lecture formula for regression error. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Model Evaluation lecture; Formula check; regression error -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For regression error, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Rewrite resampling intuition in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Model Evaluation lecture; Matrix notation and shape check; resampling intuition -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For resampling intuition, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Fill in the omitted algebraic step that connects complex models to the next displayed formula in the lecture.
#
# <!-- Source: Model Evaluation lecture; Omitted algebra; complex models -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For complex models, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Derive the first-order condition or one-step update associated with underfitting, making clear which loss or objective is being differentiated.
#
# <!-- Source: Model Evaluation lecture; Gap-filling derivation; underfitting -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For underfitting, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Classify the following situation for honest evaluation: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Model Evaluation lecture; Conceptual classification; honest evaluation -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For honest evaluation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Perturb one observation or one feature scale. Determine whether evaluation versus learning changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Model Evaluation lecture; Sensitivity check; evaluation versus learning -->
#
# <details>
# <summary>Answer</summary>
#
# The target is performance on fresh data, not on observations used to fit $\hat f$. Optimism occurs because the training sample influenced the fitted rule; held-out or nested evaluation restores separation. For evaluation versus learning, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
