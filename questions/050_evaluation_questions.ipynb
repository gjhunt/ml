# %% [markdown]
# # Model Evaluation
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# For training performance versus target performance, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For training performance versus target performance, why can the apparent performance diffe -->
#
# <details>
# <summary>Answer</summary>
#
# For training performance versus target performance, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 2
#
# For test data, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For test data, why can the apparent performance differ from performance on new data, and w -->
#
# <details>
# <summary>Answer</summary>
#
# For test data, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 3
#
# For overfitting, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For overfitting, why can the apparent performance differ from performance on new data, and -->
#
# <details>
# <summary>Answer</summary>
#
# For overfitting, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 4
#
# For model complexity, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For model complexity, why can the apparent performance differ from performance on new data -->
#
# <details>
# <summary>Answer</summary>
#
# For model complexity, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 5
#
# For simulation evidence, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For simulation evidence, why can the apparent performance differ from performance on new d -->
#
# <details>
# <summary>Answer</summary>
#
# For simulation evidence, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For why training data are informative but biased, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For why training data are informative but biased, why can the apparent performance differ  -->
#
# <details>
# <summary>Answer</summary>
#
# For why training data are informative but biased, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 7
#
# For generalization error, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For generalization error, why can the apparent performance differ from performance on new  -->
#
# <details>
# <summary>Answer</summary>
#
# For generalization error, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 8
#
# For held-out evaluation, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For held-out evaluation, why can the apparent performance differ from performance on new d -->
#
# <details>
# <summary>Answer</summary>
#
# For held-out evaluation, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 9
#
# For using all data for fitting, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For using all data for fitting, why can the apparent performance differ from performance o -->
#
# <details>
# <summary>Answer</summary>
#
# For using all data for fitting, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 10
#
# For the final reported model, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For the final reported model, why can the apparent performance differ from performance on  -->
#
# <details>
# <summary>Answer</summary>
#
# For the final reported model, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 11
#
# For variance in evaluation estimates, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For variance in evaluation estimates, why can the apparent performance differ from perform -->
#
# <details>
# <summary>Answer</summary>
#
# For variance in evaluation estimates, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 12
#
# For data leakage, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For data leakage, why can the apparent performance differ from performance on new data, an -->
#
# <details>
# <summary>Answer</summary>
#
# For data leakage, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 13
#
# For choosing performance metrics, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For choosing performance metrics, why can the apparent performance differ from performance -->
#
# <details>
# <summary>Answer</summary>
#
# For choosing performance metrics, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 14
#
# For classification accuracy, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For classification accuracy, why can the apparent performance differ from performance on n -->
#
# <details>
# <summary>Answer</summary>
#
# For classification accuracy, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 15
#
# For regression error, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For regression error, why can the apparent performance differ from performance on new data -->
#
# <details>
# <summary>Answer</summary>
#
# For regression error, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 16
#
# For resampling intuition, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For resampling intuition, why can the apparent performance differ from performance on new  -->
#
# <details>
# <summary>Answer</summary>
#
# For resampling intuition, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 17
#
# For complex models, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For complex models, why can the apparent performance differ from performance on new data,  -->
#
# <details>
# <summary>Answer</summary>
#
# For complex models, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 18
#
# For underfitting, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For underfitting, why can the apparent performance differ from performance on new data, an -->
#
# <details>
# <summary>Answer</summary>
#
# For underfitting, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 19
#
# For honest evaluation, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For honest evaluation, why can the apparent performance differ from performance on new dat -->
#
# <details>
# <summary>Answer</summary>
#
# For honest evaluation, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>

# %% [markdown]
# ### Question 20
#
# For the evaluation/learning separation, why can the apparent performance differ from performance on new data, and what evaluation practice addresses this?
#
# <!-- Source: Model Evaluation lecture; section related to: For the evaluation/learning separation, why can the apparent performance differ from perfo -->
#
# <details>
# <summary>Answer</summary>
#
# For the evaluation/learning separation, the central distinction is between performance on fitted data and performance on new data. Honest held-out evaluation estimates generalization, while repeated use of evaluation data feeds information back into modeling and biases the estimate downward.
#
# </details>
