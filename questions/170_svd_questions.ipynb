# %% [markdown]
# # Singular Value Decomposition
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Using the lecture's treatment of diagonal matrices, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For diagonal matrices, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Using the lecture's treatment of orthogonal matrices preserving distances, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For orthogonal matrices preserving distances, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Using the lecture's treatment of eigenvalues and eigenvectors, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For eigenvalues and eigenvectors, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Using the lecture's treatment of diagonalization, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For diagonalization, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Using the lecture's treatment of symmetric orthogonal diagonalization, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For symmetric orthogonal diagonalization, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Using the lecture's treatment of the SVD $A=U\Sigma V^T$, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For the SVD $A=U\Sigma V^T$, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Using the lecture's treatment of singular values, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For singular values, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Using the lecture's treatment of right singular vectors, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For right singular vectors, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Using the lecture's treatment of left singular vectors, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For left singular vectors, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Using the lecture's treatment of outer-product form, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For outer-product form, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Using the lecture's treatment of SVD versus eigendecomposition, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For SVD versus eigendecomposition, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Using the lecture's treatment of geometric interpretation, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For geometric interpretation, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Using the lecture's treatment of full SVD, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For full SVD, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Using the lecture's treatment of reduced SVD, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For reduced SVD, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Using the lecture's treatment of truncated SVD, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For truncated SVD, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Using the lecture's treatment of rank, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For rank, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Using the lecture's treatment of low-rank approximation, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For low-rank approximation, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Using the lecture's treatment of the Eckart--Young idea, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For the Eckart--Young idea, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Using the lecture's treatment of computing singular values from $A^TA$, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For computing singular values from $A^TA$, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Using the lecture's treatment of numerical examples, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For numerical examples, SVD writes $A=U\Sigma V^T$ with orthonormal singular vectors and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and another rotation/reflection, and truncated SVD gives optimal low-rank approximations.
#
# </details>
