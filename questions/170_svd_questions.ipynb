# %% [markdown]
# # Singular Value Decomposition
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Rewrite diagonal matrices in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Singular Value Decomposition lecture; Matrix notation and shape check; diagonal matrices -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For diagonal matrices, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Fill in the omitted algebraic step that connects orthogonal distance preservation to the next displayed formula in the lecture.
#
# <!-- Source: Singular Value Decomposition lecture; Omitted algebra; orthogonal distance preservation -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For orthogonal distance preservation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Derive the first-order condition or one-step update associated with eigenvalue equation, making clear which loss or objective is being differentiated.
#
# <!-- Source: Singular Value Decomposition lecture; Gap-filling derivation; eigenvalue equation -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For eigenvalue equation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Classify the following situation for diagonalization: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Singular Value Decomposition lecture; Conceptual classification; diagonalization -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For diagonalization, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Perturb one observation or one feature scale. Determine whether symmetric orthogonal diagonalization changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Singular Value Decomposition lecture; Sensitivity check; symmetric orthogonal diagonalization -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For symmetric orthogonal diagonalization, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# A student claims that SVD factorization is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Singular Value Decomposition lecture; False-claim diagnosis; SVD factorization -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For SVD factorization, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Take the relevant tuning parameter or sample size in singular values to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Singular Value Decomposition lecture; Boundary case; singular values -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 8
#
# State the prediction or decision rule associated with right singular vectors; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Singular Value Decomposition lecture; Prediction rule; right singular vectors -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For right singular vectors, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of left singular vectors. Verify the example in one or two equations.
#
# <!-- Source: Singular Value Decomposition lecture; Counterexample or edge case; left singular vectors -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For left singular vectors, use the lecture formulas to compute the relevant quantity before and after the assumption fails. The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Prove the easy implication involving outer-product form, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Singular Value Decomposition lecture; One direction and converse; outer-product form -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For outer-product form, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Verify the monotonicity, convexity, or non-increase property asserted for SVD versus eigendecomposition; state exactly what is monotone or convex.
#
# <!-- Source: Singular Value Decomposition lecture; Property verification; SVD versus eigendecomposition -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For SVD versus eigendecomposition, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Compare geometric interpretation with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Singular Value Decomposition lecture; Precise comparison; geometric interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For geometric interpretation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Express full SVD as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Singular Value Decomposition lecture; ERM translation; full SVD -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For full SVD, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Design a compact diagnostic for detecting a problem with reduced SVD using only quantities introduced in the lecture.
#
# <!-- Source: Singular Value Decomposition lecture; Diagnostic; reduced SVD -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For reduced SVD, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# On a toy sample with two observations, compute the lecture quantity behind truncated SVD; use symbols if the lecture did not give numbers.
#
# <!-- Source: Singular Value Decomposition lecture; Small computation; truncated SVD -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Use the lecture geometry to describe rank as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Singular Value Decomposition lecture; Geometric interpretation; rank -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Connect low-rank approximation to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Singular Value Decomposition lecture; Concept bridge; low-rank approximation -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For low-rank approximation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Identify the nontrivial assumption that makes the lecture statement about Eckart--Young theorem valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Singular Value Decomposition lecture; Hypothesis check; Eckart--Young theorem -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 19
#
# For the algorithmic step involving singular values from $A^TA$, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Singular Value Decomposition lecture; Algorithm step; singular values from $A^TA$ -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For singular values from $A^TA$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Write the lecture formula for worked numerical example. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Singular Value Decomposition lecture; Formula check; worked numerical example -->
#
# <details>
# <summary>Answer</summary>
#
# The SVD writes $A=U\Sigma V^T$, connecting singular vectors to eigenvectors of $A^TA$ and $AA^T$. Geometrically, it rotates or reflects, scales along orthogonal axes, then rotates or reflects again. For worked numerical example, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
