# %% [markdown]
# # Singular Value Decomposition
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for diagonal matrices and identify how it enters the objective or prediction rule.
#
# <!-- Source: Singular Value Decomposition lecture; diagonal matrices -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for orthogonal distance preservation, stating all assumptions.
#
# <!-- Source: Singular Value Decomposition lecture; orthogonal distance preservation -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about eigenvalue equation: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Singular Value Decomposition lecture; eigenvalue equation -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with diagonalization when the relevant lecture assumption is removed.
#
# <!-- Source: Singular Value Decomposition lecture; diagonalization -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely symmetric orthogonal diagonalization with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Singular Value Decomposition lecture; symmetric orthogonal diagonalization -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for SVD factorization and interpret the sign or magnitude.
#
# <!-- Source: Singular Value Decomposition lecture; SVD factorization -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make singular values well-defined.
#
# <!-- Source: Singular Value Decomposition lecture; singular values -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for right singular vectors in matrix notation and name each term.
#
# <!-- Source: Singular Value Decomposition lecture; right singular vectors -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about left singular vectors; justify the decision with a formula.
#
# <!-- Source: Singular Value Decomposition lecture; left singular vectors -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for outer-product form under the relevant tuning parameter.
#
# <!-- Source: Singular Value Decomposition lecture; outer-product form -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of SVD versus eigendecomposition in the lecture's model class.
#
# <!-- Source: Singular Value Decomposition lecture; SVD versus eigendecomposition -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely geometric interpretation into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Singular Value Decomposition lecture; geometric interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize full SVD as a projection, partition, or transformation.
#
# <!-- Source: Singular Value Decomposition lecture; full SVD -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining reduced SVD and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Singular Value Decomposition lecture; reduced SVD -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving truncated SVD; which one fails in the common edge case?
#
# <!-- Source: Singular Value Decomposition lecture; truncated SVD -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how rank changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Singular Value Decomposition lecture; rank -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with low-rank approximation and resolve ties if needed.
#
# <!-- Source: Singular Value Decomposition lecture; low-rank approximation -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for Eckart--Young theorem.
#
# <!-- Source: Singular Value Decomposition lecture; Eckart--Young theorem -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for singular values from $A^TA$ using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Singular Value Decomposition lecture; singular values from $A^TA$ -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize worked numerical example by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Singular Value Decomposition lecture; worked numerical example -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is SVD writes $A=U\Sigma V^T$ with orthonormal columns and nonnegative singular values. It decomposes a linear map into rotation/reflection, coordinate scaling, and rotation/reflection; truncation gives low-rank structure.
#
# </details>
