# %% [markdown]
# # Linear Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# A student claims that squared-error empirical risk is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Linear Regression lecture; False-claim diagnosis; squared-error empirical risk -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For squared-error empirical risk, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Take the relevant tuning parameter or sample size in normal equations to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Linear Regression lecture; Boundary case; normal equations -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 3
#
# State the prediction or decision rule associated with projection interpretation; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Linear Regression lecture; Prediction rule; projection interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For projection interpretation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of hat matrix. Verify the example in one or two equations.
#
# <!-- Source: Linear Regression lecture; Counterexample or edge case; hat matrix -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For hat matrix, use the lecture formulas to compute the relevant quantity before and after the assumption fails. least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Prove the easy implication involving intercepts, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Linear Regression lecture; One direction and converse; intercepts -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For intercepts, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Verify the monotonicity, convexity, or non-increase property asserted for one-hot encoding; state exactly what is monotone or convex.
#
# <!-- Source: Linear Regression lecture; Property verification; one-hot encoding -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For one-hot encoding, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Compare baseline categories with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Linear Regression lecture; Precise comparison; baseline categories -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For baseline categories, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Express polynomial basis expansion as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Linear Regression lecture; ERM translation; polynomial basis expansion -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For polynomial basis expansion, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Design a compact diagnostic for detecting a problem with outlier sensitivity using only quantities introduced in the lecture.
#
# <!-- Source: Linear Regression lecture; Diagnostic; outlier sensitivity -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For outlier sensitivity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# On a toy sample with two observations, compute the lecture quantity behind rank deficiency; use symbols if the lecture did not give numbers.
#
# <!-- Source: Linear Regression lecture; Small computation; rank deficiency -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Use the lecture geometry to describe Moore--Penrose solution as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Linear Regression lecture; Geometric interpretation; Moore--Penrose solution -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Connect collinearity and stability to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Linear Regression lecture; Concept bridge; collinearity and stability -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For collinearity and stability, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Identify the nontrivial assumption that makes the lecture statement about training predictions valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Linear Regression lecture; Hypothesis check; training predictions -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 14
#
# For the algorithmic step involving linearity in parameters, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Linear Regression lecture; Algorithm step; linearity in parameters -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For linearity in parameters, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Write the lecture formula for feature transformations. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Linear Regression lecture; Formula check; feature transformations -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For feature transformations, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Rewrite residual orthogonality in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Linear Regression lecture; Matrix notation and shape check; residual orthogonality -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For residual orthogonality, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Fill in the omitted algebraic step that connects convexity of least squares to the next displayed formula in the lecture.
#
# <!-- Source: Linear Regression lecture; Omitted algebra; convexity of least squares -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For convexity of least squares, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Derive the first-order condition or one-step update associated with ill-posed simulated data, making clear which loss or objective is being differentiated.
#
# <!-- Source: Linear Regression lecture; Gap-filling derivation; ill-posed simulated data -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For ill-posed simulated data, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Classify the following situation for real-data coefficient interpretation: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Linear Regression lecture; Conceptual classification; real-data coefficient interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For real-data coefficient interpretation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Perturb one observation or one feature scale. Determine whether limitations of raw-feature linearity changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Linear Regression lecture; Sensitivity check; limitations of raw-feature linearity -->
#
# <details>
# <summary>Answer</summary>
#
# least squares solves $\min_w\|y-Xw\|^2$; differentiating gives $X^T(X\hat w-y)=0$, and $X\hat w$ is the projection of $y$ onto $\operatorname{col}(X)$. The key distinction is whether the issue changes the column space of $X$, the uniqueness of $\hat w$, or the interpretation of a coefficient. For limitations of raw-feature linearity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
