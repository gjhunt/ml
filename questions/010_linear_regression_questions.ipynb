# %% [markdown]
# # Linear Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Using the lecture's treatment of squared-error empirical risk, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, squared-error empirical risk is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Using the lecture's treatment of normal equations, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, normal equations is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Using the lecture's treatment of the projection interpretation, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, the projection interpretation is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Using the lecture's treatment of the hat matrix, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, the hat matrix is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Using the lecture's treatment of intercepts, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, intercepts is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Using the lecture's treatment of one-hot encoding, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, one-hot encoding is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Using the lecture's treatment of baseline categories, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, baseline categories is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Using the lecture's treatment of polynomial regression as basis expansion, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, polynomial regression as basis expansion is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Using the lecture's treatment of outlier sensitivity, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, outlier sensitivity is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Using the lecture's treatment of rank deficiency, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, rank deficiency is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Using the lecture's treatment of the Moore--Penrose solution, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, the Moore--Penrose solution is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Using the lecture's treatment of collinearity and stability, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, collinearity and stability is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Using the lecture's treatment of training predictions, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, training predictions is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Using the lecture's treatment of linearity in parameters, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, linearity in parameters is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Using the lecture's treatment of feature transformations, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, feature transformations is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Using the lecture's treatment of residual orthogonality, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, residual orthogonality is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Using the lecture's treatment of convexity of least squares, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, convexity of least squares is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Using the lecture's treatment of ill-posed simulated data, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, ill-posed simulated data is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Using the lecture's treatment of real-data interpretation, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, real-data interpretation is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Using the lecture's treatment of limitations of linearity, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# In the lecture this is part of least-squares ERM. Mathematically, limitations of linearity is understood through minimizing $\|y-Xw\|^2$: the gradient condition $X^T(Xw-y)=0$ gives projection geometry, rank conditions determine uniqueness, and feature encodings change columns of $X$ rather than the basic optimization problem.
#
# </details>
