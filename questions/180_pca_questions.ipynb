# %% [markdown]
# # Principal Component Analysis (PCA)
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Fill in the omitted algebraic step that connects mean-centered data matrix to the next displayed formula in the lecture.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Omitted algebra; mean-centered data matrix -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For mean-centered data matrix, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the first-order condition or one-step update associated with principal component scores, making clear which loss or objective is being differentiated.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Gap-filling derivation; principal component scores -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For principal component scores, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Classify the following situation for linear-combination loadings: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Conceptual classification; linear-combination loadings -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For linear-combination loadings, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Perturb one observation or one feature scale. Determine whether projection matrices changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Sensitivity check; projection matrices -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For projection matrices, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# A student claims that PCA variance objective is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; False-claim diagnosis; PCA variance objective -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For PCA variance objective, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Take the relevant tuning parameter or sample size in covariance notation to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Boundary case; covariance notation -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 7
#
# State the prediction or decision rule associated with Rayleigh quotient theorem; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Prediction rule; Rayleigh quotient theorem -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For Rayleigh quotient theorem, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of first principal component. Verify the example in one or two equations.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Counterexample or edge case; first principal component -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For first principal component, use the lecture formulas to compute the relevant quantity before and after the assumption fails. PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Prove the easy implication involving orthogonality of later components, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; One direction and converse; orthogonality of later components -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For orthogonality of later components, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Verify the monotonicity, convexity, or non-increase property asserted for score properties; state exactly what is monotone or convex.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Property verification; score properties -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For score properties, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Compare connection to SVD with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Precise comparison; connection to SVD -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For connection to SVD, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Express PCA by SVD as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; ERM translation; PCA by SVD -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For PCA by SVD, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Design a compact diagnostic for detecting a problem with total variance using only quantities introduced in the lecture.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Diagnostic; total variance -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For total variance, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# On a toy sample with two observations, compute the lecture quantity behind percent variance captured; use symbols if the lecture did not give numbers.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Small computation; percent variance captured -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Use the lecture geometry to describe mean-centering as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Geometric interpretation; mean-centering -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Connect loadings interpretation to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Concept bridge; loadings interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For loadings interpretation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Identify the nontrivial assumption that makes the lecture statement about real-data variables valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Hypothesis check; real-data variables -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 18
#
# For the algorithmic step involving MNIST visualization, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Algorithm step; MNIST visualization -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For MNIST visualization, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Write the lecture formula for dimension-reduction tradeoff. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Formula check; dimension-reduction tradeoff -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For dimension-reduction tradeoff, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Rewrite reconstruction error in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Matrix notation and shape check; reconstruction error -->
#
# <details>
# <summary>Answer</summary>
#
# PCA on centered $X$ maximizes variance $\|Xu\|^2$ subject to $\|u\|=1$ and is computed from covariance eigenvectors or the SVD. Variance explained comes from singular values squared, and centering is essential for interpreting variance around the mean. For reconstruction error, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
