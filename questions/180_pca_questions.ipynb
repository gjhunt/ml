# %% [markdown]
# # Principal Component Analysis (PCA)
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Using the lecture's treatment of mean-centered data matrix $X$, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For mean-centered data matrix $X$, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Using the lecture's treatment of principal component scores, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For principal component scores, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Using the lecture's treatment of linear combinations of variables, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For linear combinations of variables, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Using the lecture's treatment of projection matrices, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For projection matrices, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Using the lecture's treatment of the PCA variance objective, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For the PCA variance objective, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Using the lecture's treatment of covariance notation, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For covariance notation, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Using the lecture's treatment of Rayleigh quotient theorem, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For Rayleigh quotient theorem, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Using the lecture's treatment of first principal component, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For first principal component, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Using the lecture's treatment of orthogonality of later components, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For orthogonality of later components, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Using the lecture's treatment of score properties, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For score properties, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Using the lecture's treatment of connection to SVD, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For connection to SVD, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Using the lecture's treatment of PCA by SVD, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For PCA by SVD, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Using the lecture's treatment of total variance, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For total variance, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Using the lecture's treatment of percent variance captured, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For percent variance captured, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Using the lecture's treatment of mean-centering, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For mean-centering, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Using the lecture's treatment of loadings, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For loadings, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Using the lecture's treatment of interpreting loadings, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For interpreting loadings, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Using the lecture's treatment of high-dimensional visualization, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For high-dimensional visualization, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Using the lecture's treatment of MNIST PCA, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For MNIST PCA, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Using the lecture's treatment of dimension reduction tradeoffs, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For dimension reduction tradeoffs, PCA finds orthonormal directions maximizing variance of centered data. The Rayleigh quotient links the solution to covariance eigenvectors, and the SVD of the centered data computes scores, loadings, and variance explained.
#
# </details>
