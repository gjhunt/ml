# %% [markdown]
# # Principal Component Analysis (PCA)
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for mean-centered data matrix and identify how it enters the objective or prediction rule.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; mean-centered data matrix -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for principal component scores, stating all assumptions.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; principal component scores -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about linear-combination loadings: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; linear-combination loadings -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with projection matrices when the relevant lecture assumption is removed.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; projection matrices -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely PCA variance objective with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; PCA variance objective -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for covariance notation and interpret the sign or magnitude.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; covariance notation -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make Rayleigh quotient theorem well-defined.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; Rayleigh quotient theorem -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for first principal component in matrix notation and name each term.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; first principal component -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about orthogonality of later components; justify the decision with a formula.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; orthogonality of later components -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for score properties under the relevant tuning parameter.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; score properties -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of connection to SVD in the lecture's model class.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; connection to SVD -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely PCA by SVD into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; PCA by SVD -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize total variance as a projection, partition, or transformation.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; total variance -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining percent variance captured and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; percent variance captured -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving mean-centering; which one fails in the common edge case?
#
# <!-- Source: Principal Component Analysis (PCA) lecture; mean-centering -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how loadings interpretation changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; loadings interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with real-data variables and resolve ties if needed.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; real-data variables -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for MNIST visualization.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; MNIST visualization -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for dimension-reduction tradeoff using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; dimension-reduction tradeoff -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize reconstruction error by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Principal Component Analysis (PCA) lecture; reconstruction error -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is PCA on centered $X$ maximizes variance of $Xu$ subject to $\|u\|=1$, solved by covariance eigenvectors or the SVD of $X$. Variance explained is measured by singular values squared.
#
# </details>
