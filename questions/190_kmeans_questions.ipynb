# %% [markdown]
# # K-means
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for clustering from $X$ alone and identify how it enters the objective or prediction rule.
#
# <!-- Source: K-means lecture; clustering from $X$ alone -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for cluster assignments, stating all assumptions.
#
# <!-- Source: K-means lecture; cluster assignments -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about centroids: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: K-means lecture; centroids -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with k-means objective when the relevant lecture assumption is removed.
#
# <!-- Source: K-means lecture; k-means objective -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely within-cluster sum of squares with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: K-means lecture; within-cluster sum of squares -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for Lloyd assignment step and interpret the sign or magnitude.
#
# <!-- Source: K-means lecture; Lloyd assignment step -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make Lloyd update step well-defined.
#
# <!-- Source: K-means lecture; Lloyd update step -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for monotone decrease in matrix notation and name each term.
#
# <!-- Source: K-means lecture; monotone decrease -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about local minima; justify the decision with a formula.
#
# <!-- Source: K-means lecture; local minima -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for package solution variability under the relevant tuning parameter.
#
# <!-- Source: K-means lecture; package solution variability -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of choosing $K$ in the lecture's model class.
#
# <!-- Source: K-means lecture; choosing $K$ -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely scaling matters into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: K-means lecture; scaling matters -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize spherical cluster assumption as a projection, partition, or transformation.
#
# <!-- Source: K-means lecture; spherical cluster assumption -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining nonconvex cluster failure and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: K-means lecture; nonconvex cluster failure -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving wine chemistry variables; which one fails in the common edge case?
#
# <!-- Source: K-means lecture; wine chemistry variables -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how PCA visualization changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: K-means lecture; PCA visualization -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with initialization and resolve ties if needed.
#
# <!-- Source: K-means lecture; initialization -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for empty clusters.
#
# <!-- Source: K-means lecture; empty clusters -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for unsupervised evaluation using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: K-means lecture; unsupervised evaluation -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize centroid interpretation by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: K-means lecture; centroid interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is k-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$. Lloyd assignment picks nearest centroids and the update sets each centroid to its cluster mean, so each step does not increase the objective.
#
# </details>
