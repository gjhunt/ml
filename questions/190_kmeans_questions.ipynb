# %% [markdown]
# # K-means
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Using the lecture's treatment of clustering from $X$ alone, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For clustering from $X$ alone, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Using the lecture's treatment of cluster assignments, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For cluster assignments, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Using the lecture's treatment of centroids, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For centroids, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Using the lecture's treatment of the k-means objective, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For the k-means objective, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Using the lecture's treatment of within-cluster sum of squares, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For within-cluster sum of squares, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Using the lecture's treatment of Lloyd assignment step, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For Lloyd assignment step, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Using the lecture's treatment of Lloyd update step, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For Lloyd update step, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Using the lecture's treatment of monotonic decrease, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For monotonic decrease, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Using the lecture's treatment of local minima, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For local minima, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Using the lecture's treatment of using a package, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For using a package, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Using the lecture's treatment of choosing number of clusters, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For choosing number of clusters, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Using the lecture's treatment of scaling matters, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For scaling matters, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Using the lecture's treatment of spherical clusters, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For spherical clusters, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Using the lecture's treatment of failure on nonconvex clusters, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For failure on nonconvex clusters, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Using the lecture's treatment of wine chemistry data, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For wine chemistry data, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Using the lecture's treatment of PCA visualization, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For PCA visualization, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Using the lecture's treatment of initialization, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For initialization, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Using the lecture's treatment of empty clusters, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For empty clusters, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Using the lecture's treatment of unsupervised evaluation, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For unsupervised evaluation, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Using the lecture's treatment of centroid interpretation, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# For centroid interpretation, k-means minimizes within-cluster squared distances to centroids. Lloyd’s algorithm alternates nearest-centroid assignment and centroid recomputation; each step does not increase the objective, but the final solution may be only local.
#
# </details>
