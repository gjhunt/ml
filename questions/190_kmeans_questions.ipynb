# %% [markdown]
# # K-means
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Use the lecture geometry to describe clustering from $X$ alone as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: K-means lecture; Geometric interpretation; clustering from $X$ alone -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Connect cluster assignments to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: K-means lecture; Concept bridge; cluster assignments -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For cluster assignments, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Identify the nontrivial assumption that makes the lecture statement about centroids valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: K-means lecture; Hypothesis check; centroids -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 4
#
# For the algorithmic step involving k-means objective, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: K-means lecture; Algorithm step; k-means objective -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For k-means objective, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Write the lecture formula for within-cluster sum of squares. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: K-means lecture; Formula check; within-cluster sum of squares -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For within-cluster sum of squares, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Rewrite Lloyd assignment step in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: K-means lecture; Matrix notation and shape check; Lloyd assignment step -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For Lloyd assignment step, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Fill in the omitted algebraic step that connects Lloyd update step to the next displayed formula in the lecture.
#
# <!-- Source: K-means lecture; Omitted algebra; Lloyd update step -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For Lloyd update step, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Derive the first-order condition or one-step update associated with monotone decrease, making clear which loss or objective is being differentiated.
#
# <!-- Source: K-means lecture; Gap-filling derivation; monotone decrease -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For monotone decrease, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Classify the following situation for local minima: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: K-means lecture; Conceptual classification; local minima -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For local minima, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Perturb one observation or one feature scale. Determine whether package solution variability changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: K-means lecture; Sensitivity check; package solution variability -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For package solution variability, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# A student claims that choosing $K$ is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: K-means lecture; False-claim diagnosis; choosing $K$ -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For choosing $K$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Take the relevant tuning parameter or sample size in scaling matters to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: K-means lecture; Boundary case; scaling matters -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 13
#
# State the prediction or decision rule associated with spherical cluster assumption; include how ties or non-uniqueness should be handled.
#
# <!-- Source: K-means lecture; Prediction rule; spherical cluster assumption -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For spherical cluster assumption, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of nonconvex cluster failure. Verify the example in one or two equations.
#
# <!-- Source: K-means lecture; Counterexample or edge case; nonconvex cluster failure -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For nonconvex cluster failure, use the lecture formulas to compute the relevant quantity before and after the assumption fails. K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Prove the easy implication involving wine chemistry variables, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: K-means lecture; One direction and converse; wine chemistry variables -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For wine chemistry variables, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Verify the monotonicity, convexity, or non-increase property asserted for PCA visualization; state exactly what is monotone or convex.
#
# <!-- Source: K-means lecture; Property verification; PCA visualization -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For PCA visualization, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Compare initialization with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: K-means lecture; Precise comparison; initialization -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For initialization, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Express empty clusters as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: K-means lecture; ERM translation; empty clusters -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For empty clusters, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Design a compact diagnostic for detecting a problem with unsupervised evaluation using only quantities introduced in the lecture.
#
# <!-- Source: K-means lecture; Diagnostic; unsupervised evaluation -->
#
# <details>
# <summary>Answer</summary>
#
# K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. Each Lloyd step does not increase the objective, but local minima and scaling sensitivity remain. For unsupervised evaluation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# On a toy sample with two observations, compute the lecture quantity behind centroid interpretation; use symbols if the lecture did not give numbers.
#
# <!-- Source: K-means lecture; Small computation; centroid interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. K-means minimizes $\sum_n\|x_n-\mu_{z_n}\|^2$ by alternating nearest-centroid assignments and centroid means. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>
