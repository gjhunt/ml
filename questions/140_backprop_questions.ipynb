# %% [markdown]
# # Backpropagation
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for SGD and mini-batches and identify how it enters the objective or prediction rule.
#
# <!-- Source: Backpropagation lecture; SGD and mini-batches -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for chain rule, stating all assumptions.
#
# <!-- Source: Backpropagation lecture; chain rule -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about computational graph: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Backpropagation lecture; computational graph -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with worked forward pass when the relevant lecture assumption is removed.
#
# <!-- Source: Backpropagation lecture; worked forward pass -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely loss derivative with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Backpropagation lecture; loss derivative -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for output-score derivative and interpret the sign or magnitude.
#
# <!-- Source: Backpropagation lecture; output-score derivative -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make sigmoid derivative well-defined.
#
# <!-- Source: Backpropagation lecture; sigmoid derivative -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for pre-activation derivative in matrix notation and name each term.
#
# <!-- Source: Backpropagation lecture; pre-activation derivative -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about final gradients; justify the decision with a formula.
#
# <!-- Source: Backpropagation lecture; final gradients -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for backpropagation recursion under the relevant tuning parameter.
#
# <!-- Source: Backpropagation lecture; backpropagation recursion -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of higher-dimensional chain rule in the lecture's model class.
#
# <!-- Source: Backpropagation lecture; higher-dimensional chain rule -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely vector-Jacobian products into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Backpropagation lecture; vector-Jacobian products -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize bias gradients as a projection, partition, or transformation.
#
# <!-- Source: Backpropagation lecture; bias gradients -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining batch averaging and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Backpropagation lecture; batch averaging -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving optimizer variants; which one fails in the common edge case?
#
# <!-- Source: Backpropagation lecture; optimizer variants -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how vanishing gradients changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Backpropagation lecture; vanishing gradients -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with exploding gradients and resolve ties if needed.
#
# <!-- Source: Backpropagation lecture; exploding gradients -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for finite-difference check.
#
# <!-- Source: Backpropagation lecture; finite-difference check -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for parameter sharing using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Backpropagation lecture; parameter sharing -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize efficiency of reverse mode by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Backpropagation lecture; efficiency of reverse mode -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is backprop applies the chain rule from the loss backward through the computational graph, multiplying by local derivatives and reusing upstream adjoints. This computes all parameter gradients in one reverse pass.
#
# </details>
