# %% [markdown]
# # Backpropagation
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# For computational graphs, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For computational graphs, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 2
#
# For forward pass, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For forward pass, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 3
#
# For reverse-mode differentiation, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For reverse-mode differentiation, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 4
#
# For chain rule, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For chain rule, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 5
#
# For local derivatives, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For local derivatives, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For loss gradients, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For loss gradients, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 7
#
# For layerwise affine maps, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For layerwise affine maps, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 8
#
# For activation derivatives, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For activation derivatives, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 9
#
# For ReLU derivative, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For ReLU derivative, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 10
#
# For softmax cross entropy gradients, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For softmax cross entropy gradients, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 11
#
# For parameter gradients, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For parameter gradients, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 12
#
# For vector-Jacobian products, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For vector-Jacobian products, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 13
#
# For dynamic programming of derivatives, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For dynamic programming of derivatives, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 14
#
# For backprop through multiple layers, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For backprop through multiple layers, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 15
#
# For bias gradients, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For bias gradients, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 16
#
# For batch averaging, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For batch averaging, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 17
#
# For vanishing gradients, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For vanishing gradients, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 18
#
# For exploding gradients, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For exploding gradients, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 19
#
# For manual derivative checks, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For manual derivative checks, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>

# %% [markdown]
# ### Question 20
#
# For why backprop is efficient, write the local derivative or chain-rule step used by backpropagation and explain why reverse mode is efficient.
#
# <details>
# <summary>Answer</summary>
#
# For why backprop is efficient, backpropagation applies the chain rule on a computational graph in reverse. It reuses downstream derivatives, so all parameter gradients are computed efficiently by vector-Jacobian products rather than separate derivative calculations.
#
# </details>
