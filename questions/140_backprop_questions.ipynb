# %% [markdown]
# # Backpropagation
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# On a toy sample with two observations, compute the lecture quantity behind SGD and mini-batches; use symbols if the lecture did not give numbers.
#
# <!-- Source: Backpropagation lecture; Small computation; SGD and mini-batches -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Use the lecture geometry to describe chain rule as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Backpropagation lecture; Geometric interpretation; chain rule -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Connect computational graph to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Backpropagation lecture; Concept bridge; computational graph -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For computational graph, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Identify the nontrivial assumption that makes the lecture statement about worked forward pass valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Backpropagation lecture; Hypothesis check; worked forward pass -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 5
#
# For the algorithmic step involving loss derivative, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Backpropagation lecture; Algorithm step; loss derivative -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For loss derivative, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Write the lecture formula for output-score derivative. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Backpropagation lecture; Formula check; output-score derivative -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For output-score derivative, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Rewrite sigmoid derivative in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Backpropagation lecture; Matrix notation and shape check; sigmoid derivative -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For sigmoid derivative, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Fill in the omitted algebraic step that connects pre-activation derivative to the next displayed formula in the lecture.
#
# <!-- Source: Backpropagation lecture; Omitted algebra; pre-activation derivative -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For pre-activation derivative, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Derive the first-order condition or one-step update associated with final gradients, making clear which loss or objective is being differentiated.
#
# <!-- Source: Backpropagation lecture; Gap-filling derivation; final gradients -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For final gradients, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Classify the following situation for backpropagation recursion: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Backpropagation lecture; Conceptual classification; backpropagation recursion -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For backpropagation recursion, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Perturb one observation or one feature scale. Determine whether higher-dimensional chain rule changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Backpropagation lecture; Sensitivity check; higher-dimensional chain rule -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For higher-dimensional chain rule, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# A student claims that vector-Jacobian products is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Backpropagation lecture; False-claim diagnosis; vector-Jacobian products -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For vector-Jacobian products, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Take the relevant tuning parameter or sample size in bias gradients to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Backpropagation lecture; Boundary case; bias gradients -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the prediction or decision rule associated with batch averaging; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Backpropagation lecture; Prediction rule; batch averaging -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For batch averaging, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of optimizer variants. Verify the example in one or two equations.
#
# <!-- Source: Backpropagation lecture; Counterexample or edge case; optimizer variants -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For optimizer variants, use the lecture formulas to compute the relevant quantity before and after the assumption fails. Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Prove the easy implication involving vanishing gradients, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Backpropagation lecture; One direction and converse; vanishing gradients -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For vanishing gradients, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Verify the monotonicity, convexity, or non-increase property asserted for exploding gradients; state exactly what is monotone or convex.
#
# <!-- Source: Backpropagation lecture; Property verification; exploding gradients -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For exploding gradients, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Compare finite-difference check with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Backpropagation lecture; Precise comparison; finite-difference check -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For finite-difference check, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Express parameter sharing as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Backpropagation lecture; ERM translation; parameter sharing -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For parameter sharing, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Design a compact diagnostic for detecting a problem with efficiency of reverse mode using only quantities introduced in the lecture.
#
# <!-- Source: Backpropagation lecture; Diagnostic; efficiency of reverse mode -->
#
# <details>
# <summary>Answer</summary>
#
# Backpropagation applies the chain rule on a computational graph from the loss backward to parameters. Each local derivative is reused, which is why reverse mode computes all gradients efficiently. For efficiency of reverse mode, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
