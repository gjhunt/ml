# %% [markdown]
# # Logistic Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for sigmoid map and identify how it enters the objective or prediction rule.
#
# <!-- Source: Logistic Regression lecture; sigmoid map -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation uses $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for Bernoulli negative log-likelihood, stating all assumptions.
#
# <!-- Source: Logistic Regression lecture; Bernoulli negative log-likelihood -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about binary cross-entropy cases: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Logistic Regression lecture; binary cross-entropy cases -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification uses $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with vector-form objective when the relevant lecture assumption is removed.
#
# <!-- Source: Logistic Regression lecture; vector-form objective -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely logistic gradient with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Logistic Regression lecture; logistic gradient -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for Newton method and interpret the sign or magnitude.
#
# <!-- Source: Logistic Regression lecture; Newton method -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make Hessian $X^TWX$ well-defined.
#
# <!-- Source: Logistic Regression lecture; Hessian $X^TWX$ -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for linear decision boundaries in matrix notation and name each term.
#
# <!-- Source: Logistic Regression lecture; linear decision boundaries -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about squared error not preferred; justify the decision with a formula.
#
# <!-- Source: Logistic Regression lecture; squared error not preferred -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for separable data under the relevant tuning parameter.
#
# <!-- Source: Logistic Regression lecture; separable data -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of threshold actions in the lecture's model class.
#
# <!-- Source: Logistic Regression lecture; threshold actions -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely log-odds interpretation into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Logistic Regression lecture; log-odds interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize categorical predictors as a projection, partition, or transformation.
#
# <!-- Source: Logistic Regression lecture; categorical predictors -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining feature engineering and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Logistic Regression lecture; feature engineering -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving convexity; which one fails in the common edge case?
#
# <!-- Source: Logistic Regression lecture; convexity -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how no closed form changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Logistic Regression lecture; no closed form -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with optimization issues and resolve ties if needed.
#
# <!-- Source: Logistic Regression lecture; optimization issues -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for probability calibration.
#
# <!-- Source: Logistic Regression lecture; probability calibration -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for penguins example using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Logistic Regression lecture; penguins example -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize limitations of linear boundaries by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Logistic Regression lecture; limitations of linear boundaries -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is use $p_n=\sigma(x_n^T w)$ and loss $-y_n\log p_n-(1-y_n)\log(1-p_n)$. Its gradient is $X^T(p-y)$ and the default boundary is $x^Tw=0$.
#
# </details>
