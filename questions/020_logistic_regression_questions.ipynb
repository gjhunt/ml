# %% [markdown]
# # Logistic Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Perturb one observation or one feature scale. Determine whether sigmoid map changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Logistic Regression lecture; Sensitivity check; sigmoid map -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For sigmoid map, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# A student claims that Bernoulli negative log-likelihood is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Logistic Regression lecture; False-claim diagnosis; Bernoulli negative log-likelihood -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For Bernoulli negative log-likelihood, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Take the relevant tuning parameter or sample size in binary cross-entropy cases to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Logistic Regression lecture; Boundary case; binary cross-entropy cases -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 4
#
# State the prediction or decision rule associated with vector-form objective; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Logistic Regression lecture; Prediction rule; vector-form objective -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For vector-form objective, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of logistic gradient. Verify the example in one or two equations.
#
# <!-- Source: Logistic Regression lecture; Counterexample or edge case; logistic gradient -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For logistic gradient, use the lecture formulas to compute the relevant quantity before and after the assumption fails. Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Prove the easy implication involving Newton method, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Logistic Regression lecture; One direction and converse; Newton method -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For Newton method, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the monotonicity, convexity, or non-increase property asserted for Hessian $X^TWX$; state exactly what is monotone or convex.
#
# <!-- Source: Logistic Regression lecture; Property verification; Hessian $X^TWX$ -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For Hessian $X^TWX$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Compare linear decision boundaries with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Logistic Regression lecture; Precise comparison; linear decision boundaries -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For linear decision boundaries, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Express squared error not preferred as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Logistic Regression lecture; ERM translation; squared error not preferred -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For squared error not preferred, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Design a compact diagnostic for detecting a problem with separable data using only quantities introduced in the lecture.
#
# <!-- Source: Logistic Regression lecture; Diagnostic; separable data -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For separable data, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# On a toy sample with two observations, compute the lecture quantity behind threshold actions; use symbols if the lecture did not give numbers.
#
# <!-- Source: Logistic Regression lecture; Small computation; threshold actions -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Use the lecture geometry to describe log-odds interpretation as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Logistic Regression lecture; Geometric interpretation; log-odds interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Connect categorical predictors to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Logistic Regression lecture; Concept bridge; categorical predictors -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For categorical predictors, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Identify the nontrivial assumption that makes the lecture statement about feature engineering valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Logistic Regression lecture; Hypothesis check; feature engineering -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 15
#
# For the algorithmic step involving convexity, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Logistic Regression lecture; Algorithm step; convexity -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For convexity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Write the lecture formula for no closed form. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Logistic Regression lecture; Formula check; no closed form -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For no closed form, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Rewrite optimization issues in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Logistic Regression lecture; Matrix notation and shape check; optimization issues -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For optimization issues, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Fill in the omitted algebraic step that connects probability calibration to the next displayed formula in the lecture.
#
# <!-- Source: Logistic Regression lecture; Omitted algebra; probability calibration -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For probability calibration, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Derive the first-order condition or one-step update associated with penguins two-feature example, making clear which loss or objective is being differentiated.
#
# <!-- Source: Logistic Regression lecture; Gap-filling derivation; penguins two-feature example -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For penguins two-feature example, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Classify the following situation for limitations of linear boundaries: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Logistic Regression lecture; Conceptual classification; limitations of linear boundaries -->
#
# <details>
# <summary>Answer</summary>
#
# Binary logistic regression uses $p_n=\sigma(x_n^Tw)$ and NLL $\sum_n[-y_n\log p_n-(1-y_n)\log(1-p_n)]$, with gradient $X^T(p-y)$. The fitted score is linear, probabilities are nonlinear through $\sigma$, and the default boundary is $x^Tw=0$. For limitations of linear boundaries, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
