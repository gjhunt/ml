# %% [markdown]
# # Logistic Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Using the lecture's treatment of the sigmoid map, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For the sigmoid map, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Using the lecture's treatment of Bernoulli negative log-likelihood, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For Bernoulli negative log-likelihood, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Using the lecture's treatment of binary cross-entropy cases, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For binary cross-entropy cases, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Using the lecture's treatment of the vector-form objective, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For the vector-form objective, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Using the lecture's treatment of the logistic gradient, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For the logistic gradient, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Using the lecture's treatment of Newton versus gradient descent, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For Newton versus gradient descent, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Using the lecture's treatment of the Hessian $X^TWX$, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For the Hessian $X^TWX$, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Using the lecture's treatment of linear decision boundaries, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For linear decision boundaries, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Using the lecture's treatment of why squared error is not preferred, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For why squared error is not preferred, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Using the lecture's treatment of separable data, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For separable data, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Using the lecture's treatment of threshold actions, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For threshold actions, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Using the lecture's treatment of log-odds interpretation, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For log-odds interpretation, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Using the lecture's treatment of categorical predictors, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For categorical predictors, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Using the lecture's treatment of feature engineering, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For feature engineering, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Using the lecture's treatment of convexity, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For convexity, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Using the lecture's treatment of no closed form, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For no closed form, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Using the lecture's treatment of optimization issues, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For optimization issues, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Using the lecture's treatment of probability calibration, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For probability calibration, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Using the lecture's treatment of the penguins example, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For the penguins example, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Using the lecture's treatment of limitations of linear boundaries, give a concise mathematical explanation, derivation, or counterexample as appropriate.
#
# <details>
# <summary>Answer</summary>
#
# The key object is the Bernoulli model $p_w(x)=\sigma(w^Tx)$. For limitations of linear boundaries, the negative log-likelihood gives a convex score-based loss with gradient $X^T(p-y)$; decisions are obtained later by thresholding probabilities or scores.
#
# </details>
