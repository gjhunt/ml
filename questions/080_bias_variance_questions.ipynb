# %% [markdown]
# # Bias and Variance
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for test-error decomposition and identify how it enters the objective or prediction rule.
#
# <!-- Source: Bias and Variance lecture; test-error decomposition -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for irreducible error, stating all assumptions.
#
# <!-- Source: Bias and Variance lecture; irreducible error -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about bias term: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Bias and Variance lecture; bias term -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with variance term when the relevant lecture assumption is removed.
#
# <!-- Source: Bias and Variance lecture; variance term -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely squared-loss assumptions with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Bias and Variance lecture; squared-loss assumptions -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for model flexibility and interpret the sign or magnitude.
#
# <!-- Source: Bias and Variance lecture; model flexibility -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make underfitting well-defined.
#
# <!-- Source: Bias and Variance lecture; underfitting -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for overfitting in matrix notation and name each term.
#
# <!-- Source: Bias and Variance lecture; overfitting -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about training-data randomness; justify the decision with a formula.
#
# <!-- Source: Bias and Variance lecture; training-data randomness -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for noise role under the relevant tuning parameter.
#
# <!-- Source: Bias and Variance lecture; noise role -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of averaging reduces variance in the lecture's model class.
#
# <!-- Source: Bias and Variance lecture; averaging reduces variance -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely tradeoff curve into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Bias and Variance lecture; tradeoff curve -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize KNN example as a projection, partition, or transformation.
#
# <!-- Source: Bias and Variance lecture; KNN example -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining linear-model example and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Bias and Variance lecture; linear-model example -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving simulation interpretation; which one fails in the common edge case?
#
# <!-- Source: Bias and Variance lecture; simulation interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how MSE algebra changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Bias and Variance lecture; MSE algebra -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with estimator instability and resolve ties if needed.
#
# <!-- Source: Bias and Variance lecture; estimator instability -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for sample size effects.
#
# <!-- Source: Bias and Variance lecture; sample size effects -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for approximation error using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Bias and Variance lecture; approximation error -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize choosing complexity by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Bias and Variance lecture; choosing complexity -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is for squared loss, $\mathbb E[(Y-\hat f(X))^2]=\sigma^2+\operatorname{Bias}^2+\operatorname{Var}$ pointwise, so flexibility typically trades approximation error against estimator variability.
#
# </details>
