# %% [markdown]
# # Bias and Variance
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Design a compact diagnostic for detecting a problem with test-error decomposition using only quantities introduced in the lecture.
#
# <!-- Source: Bias and Variance lecture; Diagnostic; test-error decomposition -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For test-error decomposition, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# On a toy sample with two observations, compute the lecture quantity behind irreducible error; use symbols if the lecture did not give numbers.
#
# <!-- Source: Bias and Variance lecture; Small computation; irreducible error -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Use the lecture geometry to describe bias term as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Bias and Variance lecture; Geometric interpretation; bias term -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Connect variance term to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Bias and Variance lecture; Concept bridge; variance term -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For variance term, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Identify the nontrivial assumption that makes the lecture statement about squared-loss assumptions valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Bias and Variance lecture; Hypothesis check; squared-loss assumptions -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For the algorithmic step involving model flexibility, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Bias and Variance lecture; Algorithm step; model flexibility -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For model flexibility, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Write the lecture formula for underfitting. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Bias and Variance lecture; Formula check; underfitting -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For underfitting, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite overfitting in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Bias and Variance lecture; Matrix notation and shape check; overfitting -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For overfitting, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Fill in the omitted algebraic step that connects training-data randomness to the next displayed formula in the lecture.
#
# <!-- Source: Bias and Variance lecture; Omitted algebra; training-data randomness -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For training-data randomness, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Derive the first-order condition or one-step update associated with noise role, making clear which loss or objective is being differentiated.
#
# <!-- Source: Bias and Variance lecture; Gap-filling derivation; noise role -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For noise role, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Classify the following situation for averaging reduces variance: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Bias and Variance lecture; Conceptual classification; averaging reduces variance -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For averaging reduces variance, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Perturb one observation or one feature scale. Determine whether tradeoff curve changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Bias and Variance lecture; Sensitivity check; tradeoff curve -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For tradeoff curve, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# A student claims that KNN example is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Bias and Variance lecture; False-claim diagnosis; KNN example -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For KNN example, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Take the relevant tuning parameter or sample size in linear-model example to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Bias and Variance lecture; Boundary case; linear-model example -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 15
#
# State the prediction or decision rule associated with simulation interpretation; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Bias and Variance lecture; Prediction rule; simulation interpretation -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For simulation interpretation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of MSE algebra. Verify the example in one or two equations.
#
# <!-- Source: Bias and Variance lecture; Counterexample or edge case; MSE algebra -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For MSE algebra, use the lecture formulas to compute the relevant quantity before and after the assumption fails. Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Prove the easy implication involving estimator instability, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Bias and Variance lecture; One direction and converse; estimator instability -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For estimator instability, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Verify the monotonicity, convexity, or non-increase property asserted for sample size effects; state exactly what is monotone or convex.
#
# <!-- Source: Bias and Variance lecture; Property verification; sample size effects -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For sample size effects, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Compare approximation error with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Bias and Variance lecture; Precise comparison; approximation error -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For approximation error, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Express choosing complexity as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Bias and Variance lecture; ERM translation; choosing complexity -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared loss, pointwise error decomposes as noise plus squared bias plus variance. The decomposition is over the randomness in training data and a fresh response at the same input. For choosing complexity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
