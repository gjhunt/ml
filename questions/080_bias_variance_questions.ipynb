# %% [markdown]
# # Bias and Variance
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# State the squared-error test-error decomposition into irreducible noise, squared bias, and variance, and explain the tradeoff it illustrates.
#
# <!-- Source: Bias and Variance lecture; section related to: State the squared-error test-error decomposition into irreducible noise, squared bias, and -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about test error decomposition is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 2
#
# In the squared-error setting, explain irreducible error using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain irreducible error using the decomposition into irred -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about irreducible error is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 3
#
# In the squared-error setting, explain bias using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain bias using the decomposition into irreducible noise, -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about bias is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 4
#
# In the squared-error setting, explain variance using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain variance using the decomposition into irreducible no -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about variance is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 5
#
# In the squared-error setting, explain squared-error assumptions using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain squared-error assumptions using the decomposition in -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about squared-error assumptions is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 6
#
# In the squared-error setting, explain model flexibility using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain model flexibility using the decomposition into irred -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about model flexibility is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 7
#
# In the squared-error setting, explain underfitting using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain underfitting using the decomposition into irreducibl -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about underfitting is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 8
#
# In the squared-error setting, explain overfitting using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain overfitting using the decomposition into irreducible -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about overfitting is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 9
#
# In the squared-error setting, explain expected training data randomness using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain expected training data randomness using the decompos -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about expected training data randomness is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 10
#
# In the squared-error setting, explain the role of noise using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain the role of noise using the decomposition into irred -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about the role of noise is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 11
#
# In the squared-error setting, explain why averaging can reduce variance using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain why averaging can reduce variance using the decompos -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about why averaging can reduce variance is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 12
#
# In the squared-error setting, explain bias-variance tradeoff curves using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain bias-variance tradeoff curves using the decompositio -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about bias-variance tradeoff curves is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 13
#
# In the squared-error setting, explain KNN as an example using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain KNN as an example using the decomposition into irred -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about KNN as an example is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 14
#
# In the squared-error setting, explain linear models as an example using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain linear models as an example using the decomposition  -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about linear models as an example is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 15
#
# In the squared-error setting, explain simulation interpretation using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain simulation interpretation using the decomposition in -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about simulation interpretation is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 16
#
# In the squared-error setting, explain MSE decomposition algebra using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain MSE decomposition algebra using the decomposition in -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about MSE decomposition algebra is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 17
#
# In the squared-error setting, explain estimator instability using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain estimator instability using the decomposition into i -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about estimator instability is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 18
#
# In the squared-error setting, explain sample size effects using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain sample size effects using the decomposition into irr -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about sample size effects is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 19
#
# In the squared-error setting, explain approximation error using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain approximation error using the decomposition into irr -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about approximation error is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>

# %% [markdown]
# ### Question 20
#
# In the squared-error setting, explain choosing complexity using the decomposition into irreducible noise, squared bias, and variance.
#
# <!-- Source: Bias and Variance lecture; section related to: In the squared-error setting, explain choosing complexity using the decomposition into irr -->
#
# <details>
# <summary>Answer</summary>
#
# Under squared error, expected prediction error decomposes into noise, squared bias, and variance. The lecture’s point about choosing complexity is that model flexibility typically lowers bias but raises variance, producing a tradeoff in test error.
#
# </details>
