# %% [markdown]
# # Constrained Optimization
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# For equality constraints, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For equality constraints, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 2
#
# For Lagrange multipliers, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For Lagrange multipliers, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 3
#
# For first-order conditions, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For first-order conditions, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 4
#
# For constraint gradients, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For constraint gradients, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 5
#
# For tangent directions, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For tangent directions, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For KKT intuition, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For KKT intuition, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 7
#
# For inequality constraints, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For inequality constraints, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 8
#
# For active constraints, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For active constraints, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 9
#
# For complementary slackness, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For complementary slackness, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 10
#
# For quadratic objectives, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For quadratic objectives, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 11
#
# For projection interpretation, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For projection interpretation, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 12
#
# For ridge versus constrained forms, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For ridge versus constrained forms, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 13
#
# For lasso constraint geometry, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For lasso constraint geometry, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 14
#
# For convex feasible sets, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For convex feasible sets, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 15
#
# For normal cones, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For normal cones, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 16
#
# For boundary optima, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For boundary optima, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 17
#
# For regularization as constraint, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For regularization as constraint, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 18
#
# For dual variables, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For dual variables, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 19
#
# For simple two-variable examples, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For simple two-variable examples, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>

# %% [markdown]
# ### Question 20
#
# For checking candidate optima, state the relevant Lagrange-multiplier or KKT condition and explain how it constrains first-order improvement directions.
#
# <details>
# <summary>Answer</summary>
#
# For checking candidate optima, constrained optima satisfy first-order conditions in feasible directions. Equality constraints introduce Lagrange multipliers; inequality constraints add activity and complementary slackness, giving KKT-style conditions.
#
# </details>
