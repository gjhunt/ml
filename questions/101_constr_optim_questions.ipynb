# %% [markdown]
# # Constrained Optimization
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Compare primal problem with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Constrained Optimization lecture; Precise comparison; primal problem -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For primal problem, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Express Lagrangian as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Constrained Optimization lecture; ERM translation; Lagrangian -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For Lagrangian, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Design a compact diagnostic for detecting a problem with dual function using only quantities introduced in the lecture.
#
# <!-- Source: Constrained Optimization lecture; Diagnostic; dual function -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For dual function, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# On a toy sample with two observations, compute the lecture quantity behind weak duality; use symbols if the lecture did not give numbers.
#
# <!-- Source: Constrained Optimization lecture; Small computation; weak duality -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Use the lecture geometry to describe dual problem as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Constrained Optimization lecture; Geometric interpretation; dual problem -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Connect KKT primal feasibility to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Constrained Optimization lecture; Concept bridge; KKT primal feasibility -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For KKT primal feasibility, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Identify the nontrivial assumption that makes the lecture statement about KKT dual feasibility valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Constrained Optimization lecture; Hypothesis check; KKT dual feasibility -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 8
#
# For the algorithmic step involving stationarity, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Constrained Optimization lecture; Algorithm step; stationarity -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For stationarity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Write the lecture formula for complementary slackness. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Constrained Optimization lecture; Formula check; complementary slackness -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For complementary slackness, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Rewrite strategy for solving in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Constrained Optimization lecture; Matrix notation and shape check; strategy for solving -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For strategy for solving, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Fill in the omitted algebraic step that connects duality gap identity to the next displayed formula in the lecture.
#
# <!-- Source: Constrained Optimization lecture; Omitted algebra; duality gap identity -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For duality gap identity, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Derive the first-order condition or one-step update associated with squeeze argument, making clear which loss or objective is being differentiated.
#
# <!-- Source: Constrained Optimization lecture; Gap-filling derivation; squeeze argument -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For squeeze argument, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Classify the following situation for zero-gap conclusion: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Constrained Optimization lecture; Conceptual classification; zero-gap conclusion -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For zero-gap conclusion, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Perturb one observation or one feature scale. Determine whether constrained versus penalized form changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Constrained Optimization lecture; Sensitivity check; constrained versus penalized form -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For constrained versus penalized form, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# A student claims that active constraints is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Constrained Optimization lecture; False-claim diagnosis; active constraints -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For active constraints, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Take the relevant tuning parameter or sample size in normal/tangent directions to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Constrained Optimization lecture; Boundary case; normal/tangent directions -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 17
#
# State the prediction or decision rule associated with convex feasible sets; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Constrained Optimization lecture; Prediction rule; convex feasible sets -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For convex feasible sets, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of dual variables. Verify the example in one or two equations.
#
# <!-- Source: Constrained Optimization lecture; Counterexample or edge case; dual variables -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For dual variables, use the lecture formulas to compute the relevant quantity before and after the assumption fails. the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Prove the easy implication involving simple quadratic example, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Constrained Optimization lecture; One direction and converse; simple quadratic example -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For simple quadratic example, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Verify the monotonicity, convexity, or non-increase property asserted for checking candidate optima; state exactly what is monotone or convex.
#
# <!-- Source: Constrained Optimization lecture; Property verification; checking candidate optima -->
#
# <details>
# <summary>Answer</summary>
#
# the Lagrangian leads to dual functions, weak duality, and KKT conditions: feasibility, stationarity, dual feasibility, and complementary slackness. The gap identity explains when primal and dual certificates squeeze the optimum. For checking candidate optima, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
