# %% [markdown]
# # Constrained Optimization
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for primal problem and identify how it enters the objective or prediction rule.
#
# <!-- Source: Constrained Optimization lecture; primal problem -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for Lagrangian, stating all assumptions.
#
# <!-- Source: Constrained Optimization lecture; Lagrangian -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about dual function: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Constrained Optimization lecture; dual function -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with weak duality when the relevant lecture assumption is removed.
#
# <!-- Source: Constrained Optimization lecture; weak duality -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely dual problem with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Constrained Optimization lecture; dual problem -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for KKT primal feasibility and interpret the sign or magnitude.
#
# <!-- Source: Constrained Optimization lecture; KKT primal feasibility -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make KKT dual feasibility well-defined.
#
# <!-- Source: Constrained Optimization lecture; KKT dual feasibility -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for stationarity in matrix notation and name each term.
#
# <!-- Source: Constrained Optimization lecture; stationarity -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about complementary slackness; justify the decision with a formula.
#
# <!-- Source: Constrained Optimization lecture; complementary slackness -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for strategy for solving under the relevant tuning parameter.
#
# <!-- Source: Constrained Optimization lecture; strategy for solving -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of duality gap identity in the lecture's model class.
#
# <!-- Source: Constrained Optimization lecture; duality gap identity -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely the squeeze argument into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Constrained Optimization lecture; the squeeze argument -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize conclusion under zero gap as a projection, partition, or transformation.
#
# <!-- Source: Constrained Optimization lecture; conclusion under zero gap -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining constrained vs penalized form and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Constrained Optimization lecture; constrained vs penalized form -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving active constraints; which one fails in the common edge case?
#
# <!-- Source: Constrained Optimization lecture; active constraints -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how normal/tangent directions changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Constrained Optimization lecture; normal/tangent directions -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with convex feasible sets and resolve ties if needed.
#
# <!-- Source: Constrained Optimization lecture; convex feasible sets -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for dual variables.
#
# <!-- Source: Constrained Optimization lecture; dual variables -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for simple quadratic example using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Constrained Optimization lecture; simple quadratic example -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize checking candidate optima by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Constrained Optimization lecture; checking candidate optima -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is the Lagrangian $L(x,\lambda,
# u)$ combines objective and constraints. KKT requires feasibility, stationarity, dual feasibility, and complementary slackness; weak duality bounds primal values by dual values.
#
# </details>
