# %% [markdown]
# # Random Forests and Bagging
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Fill in the omitted algebraic step that connects single CART recap to the next displayed formula in the lecture.
#
# <!-- Source: Random Forests and Bagging lecture; Omitted algebra; single CART recap -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For single CART recap, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the first-order condition or one-step update associated with variance of averages, making clear which loss or objective is being differentiated.
#
# <!-- Source: Random Forests and Bagging lecture; Gap-filling derivation; variance of averages -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For variance of averages, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Classify the following situation for tree correlation: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Random Forests and Bagging lecture; Conceptual classification; tree correlation -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For tree correlation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Perturb one observation or one feature scale. Determine whether bootstrap samples changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Random Forests and Bagging lecture; Sensitivity check; bootstrap samples -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For bootstrap samples, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# A student claims that bagging algorithm is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Random Forests and Bagging lecture; False-claim diagnosis; bagging algorithm -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For bagging algorithm, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Take the relevant tuning parameter or sample size in regression aggregation to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Random Forests and Bagging lecture; Boundary case; regression aggregation -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. Bagging averages bootstrap trees; random forests also randomize candidate split features. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 7
#
# State the prediction or decision rule associated with classification voting; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Random Forests and Bagging lecture; Prediction rule; classification voting -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For classification voting, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of out-of-bag samples. Verify the example in one or two equations.
#
# <!-- Source: Random Forests and Bagging lecture; Counterexample or edge case; out-of-bag samples -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For out-of-bag samples, use the lecture formulas to compute the relevant quantity before and after the assumption fails. Bagging averages bootstrap trees; random forests also randomize candidate split features. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Prove the easy implication involving out-of-bag error, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Random Forests and Bagging lecture; One direction and converse; out-of-bag error -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For out-of-bag error, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Verify the monotonicity, convexity, or non-increase property asserted for bagged regression trees; state exactly what is monotone or convex.
#
# <!-- Source: Random Forests and Bagging lecture; Property verification; bagged regression trees -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For bagged regression trees, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Compare bagged classification trees with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Random Forests and Bagging lecture; Precise comparison; bagged classification trees -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For bagged classification trees, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Express random feature subsets as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Random Forests and Bagging lecture; ERM translation; random feature subsets -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For random feature subsets, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Design a compact diagnostic for detecting a problem with random forest algorithm using only quantities introduced in the lecture.
#
# <!-- Source: Random Forests and Bagging lecture; Diagnostic; random forest algorithm -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For random forest algorithm, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# On a toy sample with two observations, compute the lecture quantity behind number of trees; use symbols if the lecture did not give numbers.
#
# <!-- Source: Random Forests and Bagging lecture; Small computation; number of trees -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. Bagging averages bootstrap trees; random forests also randomize candidate split features. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Use the lecture geometry to describe feature importance as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Random Forests and Bagging lecture; Geometric interpretation; feature importance -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. This supplies both the picture and the calculation behind it.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Connect diabetes regression example to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Random Forests and Bagging lecture; Concept bridge; diabetes regression example -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For diabetes regression example, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Identify the nontrivial assumption that makes the lecture statement about breast-cancer classification example valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Random Forests and Bagging lecture; Hypothesis check; breast-cancer classification example -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. Bagging averages bootstrap trees; random forests also randomize candidate split features. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 18
#
# For the algorithmic step involving main tuning parameters, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Random Forests and Bagging lecture; Algorithm step; main tuning parameters -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For main tuning parameters, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Write the lecture formula for scaling/categorical notes. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Random Forests and Bagging lecture; Formula check; scaling/categorical notes -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For scaling/categorical notes, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Rewrite extrapolation in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Random Forests and Bagging lecture; Matrix notation and shape check; extrapolation -->
#
# <details>
# <summary>Answer</summary>
#
# Bagging averages bootstrap trees; random forests also randomize candidate split features. Averaging reduces variance most when tree errors are not too correlated, and OOB samples estimate error. For extrapolation, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>
