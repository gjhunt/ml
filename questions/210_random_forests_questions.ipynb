# %% [markdown]
# # Random Forests and Bagging
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# In random forests or bagging, explain mathematically how a single CART recap affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For a single CART recap, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 2
#
# In random forests or bagging, explain mathematically how variance of averages affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For variance of averages, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 3
#
# In random forests or bagging, explain mathematically how correlation among trees affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For correlation among trees, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 4
#
# In random forests or bagging, explain mathematically how bootstrap samples affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For bootstrap samples, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 5
#
# In random forests or bagging, explain mathematically how bagging affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For bagging, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 6
#
# In random forests or bagging, explain mathematically how regression aggregation affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For regression aggregation, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 7
#
# In random forests or bagging, explain mathematically how classification voting affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For classification voting, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 8
#
# In random forests or bagging, explain mathematically how out-of-bag samples affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For out-of-bag samples, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 9
#
# In random forests or bagging, explain mathematically how out-of-bag error affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For out-of-bag error, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 10
#
# In random forests or bagging, explain mathematically how bagged regression trees affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For bagged regression trees, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 11
#
# In random forests or bagging, explain mathematically how bagged classification trees affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For bagged classification trees, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 12
#
# In random forests or bagging, explain mathematically how random feature subsets affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For random feature subsets, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 13
#
# In random forests or bagging, explain mathematically how random forest algorithm affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For random forest algorithm, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 14
#
# In random forests or bagging, explain mathematically how number of trees affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For number of trees, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 15
#
# In random forests or bagging, explain mathematically how feature importance affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For feature importance, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 16
#
# In random forests or bagging, explain mathematically how diabetes data affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For diabetes data, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 17
#
# In random forests or bagging, explain mathematically how breast cancer data affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For breast cancer data, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 18
#
# In random forests or bagging, explain mathematically how main tuning parameters affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For main tuning parameters, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 19
#
# In random forests or bagging, explain mathematically how practical scaling notes affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For practical scaling notes, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>

# %% [markdown]
# ### Question 20
#
# In random forests or bagging, explain mathematically how interpretation tradeoffs affects averaging, correlation among trees, or out-of-bag error.
#
# <details>
# <summary>Answer</summary>
#
# For interpretation tradeoffs, bagging averages bootstrap-grown trees to reduce variance. Random forests further decorrelate trees by considering random feature subsets, so averaging is more effective than with highly correlated trees.
#
# </details>
