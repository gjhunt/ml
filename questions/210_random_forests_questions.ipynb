# %% [markdown]
# # Random Forests and Bagging
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for single CART recap and identify how it enters the objective or prediction rule.
#
# <!-- Source: Random Forests and Bagging lecture; single CART recap -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for variance of averages, stating all assumptions.
#
# <!-- Source: Random Forests and Bagging lecture; variance of averages -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about tree correlation: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Random Forests and Bagging lecture; tree correlation -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with bootstrap samples when the relevant lecture assumption is removed.
#
# <!-- Source: Random Forests and Bagging lecture; bootstrap samples -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely bagging algorithm with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Random Forests and Bagging lecture; bagging algorithm -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for regression aggregation and interpret the sign or magnitude.
#
# <!-- Source: Random Forests and Bagging lecture; regression aggregation -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make classification voting well-defined.
#
# <!-- Source: Random Forests and Bagging lecture; classification voting -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for out-of-bag samples in matrix notation and name each term.
#
# <!-- Source: Random Forests and Bagging lecture; out-of-bag samples -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about out-of-bag error; justify the decision with a formula.
#
# <!-- Source: Random Forests and Bagging lecture; out-of-bag error -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for bagged regression trees under the relevant tuning parameter.
#
# <!-- Source: Random Forests and Bagging lecture; bagged regression trees -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of bagged classification trees in the lecture's model class.
#
# <!-- Source: Random Forests and Bagging lecture; bagged classification trees -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely random feature subsets into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Random Forests and Bagging lecture; random feature subsets -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize random forest algorithm as a projection, partition, or transformation.
#
# <!-- Source: Random Forests and Bagging lecture; random forest algorithm -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining number of trees and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Random Forests and Bagging lecture; number of trees -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving feature importance; which one fails in the common edge case?
#
# <!-- Source: Random Forests and Bagging lecture; feature importance -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how diabetes regression example changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Random Forests and Bagging lecture; diabetes regression example -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with breast-cancer classification example and resolve ties if needed.
#
# <!-- Source: Random Forests and Bagging lecture; breast-cancer classification example -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for main tuning parameters.
#
# <!-- Source: Random Forests and Bagging lecture; main tuning parameters -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for scaling/categorical notes using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Random Forests and Bagging lecture; scaling/categorical notes -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize extrapolation by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Random Forests and Bagging lecture; extrapolation -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is bagging averages bootstrap trees; variance of an average falls most when tree errors are weakly correlated. Random feature subsets reduce correlation, and out-of-bag samples estimate error without a separate holdout.
#
# </details>
