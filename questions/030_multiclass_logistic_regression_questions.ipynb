# %% [markdown]
# # Multiclass Logistic Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Connect linear class scores to a later or earlier lecture object by writing one shared formula and one mathematical difference.
#
# <!-- Source: Multiclass Logistic Regression lecture; Concept bridge; linear class scores -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For linear class scores, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Identify the nontrivial assumption that makes the lecture statement about softmax probabilities valid. Give a counterexample outline when that assumption is absent.
#
# <!-- Source: Multiclass Logistic Regression lecture; Hypothesis check; softmax probabilities -->
#
# <details>
# <summary>Answer</summary>
#
# The nontrivial condition is the one that makes the displayed operation well-defined or the minimizer unique. softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. If the condition is removed, the conclusion can fail through non-uniqueness, instability, non-identifiability, or biased evaluation depending on the lecture section.
#
# </details>

# %% [markdown]
# ### Question 3
#
# For the algorithmic step involving one-hot labels, specify the input to the step, the quantity minimized, and the output of the step.
#
# <!-- Source: Multiclass Logistic Regression lecture; Algorithm step; one-hot labels -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For one-hot labels, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Write the lecture formula for cross-entropy loss. Then name one quantity in the formula that would change if the data matrix were rescaled.
#
# <!-- Source: Multiclass Logistic Regression lecture; Formula check; cross-entropy loss -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For cross-entropy loss, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Rewrite log-sum-exp term in the lecture matrix notation and check the dimensions of every factor.
#
# <!-- Source: Multiclass Logistic Regression lecture; Matrix notation and shape check; log-sum-exp term -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For log-sum-exp term, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 6
#
# Fill in the omitted algebraic step that connects matrix-form scores $XW$ to the next displayed formula in the lecture.
#
# <!-- Source: Multiclass Logistic Regression lecture; Omitted algebra; matrix-form scores $XW$ -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For matrix-form scores $XW$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Derive the first-order condition or one-step update associated with gradient $X^T(P-Y)$, making clear which loss or objective is being differentiated.
#
# <!-- Source: Multiclass Logistic Regression lecture; Gap-filling derivation; gradient $X^T(P-Y)$ -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For gradient $X^T(P-Y)$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Classify the following situation for identifiability: does it affect fitting, prediction, evaluation, or interpretation? Defend the classification mathematically.
#
# <!-- Source: Multiclass Logistic Regression lecture; Conceptual classification; identifiability -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For identifiability, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Perturb one observation or one feature scale. Determine whether reference-class constraints changes continuously, discontinuously, or not at all, and justify the answer.
#
# <!-- Source: Multiclass Logistic Regression lecture; Sensitivity check; reference-class constraints -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For reference-class constraints, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 10
#
# A student claims that argmax decision rules is unaffected by every invertible reparameterization of the inputs. Decide whether the claim is true in this lecture setting, and justify the answer.
#
# <!-- Source: Multiclass Logistic Regression lecture; False-claim diagnosis; argmax decision rules -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For argmax decision rules, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Take the relevant tuning parameter or sample size in pairwise decision boundaries to an extreme value. Compute the limiting object and interpret it.
#
# <!-- Source: Multiclass Logistic Regression lecture; Boundary case; pairwise decision boundaries -->
#
# <details>
# <summary>Answer</summary>
#
# Take the parameter in the lecture formula to the stated extreme and simplify before interpreting. softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. The limiting object usually becomes an unregularized fit, an over-smoothed fit, a degenerate classifier, or a fully constrained model.
#
# </details>

# %% [markdown]
# ### Question 12
#
# State the prediction or decision rule associated with feature engineering; include how ties or non-uniqueness should be handled.
#
# <!-- Source: Multiclass Logistic Regression lecture; Prediction rule; feature engineering -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For feature engineering, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Construct the smallest concrete example you can that exposes a limitation or edge case of MNIST linear classifier. Verify the example in one or two equations.
#
# <!-- Source: Multiclass Logistic Regression lecture; Counterexample or edge case; MNIST linear classifier -->
#
# <details>
# <summary>Answer</summary>
#
# One compact construction should isolate the lecture assumption. For MNIST linear classifier, use the lecture formulas to compute the relevant quantity before and after the assumption fails. softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Thus the example is valid only if it changes that quantity while keeping the surrounding setup fixed.
#
# </details>

# %% [markdown]
# ### Question 14
#
# Prove the easy implication involving one-vs-rest comparison, then state whether the converse is true; if not, give a compact counterexample.
#
# <!-- Source: Multiclass Logistic Regression lecture; One direction and converse; one-vs-rest comparison -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For one-vs-rest comparison, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 15
#
# Verify the monotonicity, convexity, or non-increase property asserted for equal-score loss $\log K$; state exactly what is monotone or convex.
#
# <!-- Source: Multiclass Logistic Regression lecture; Property verification; equal-score loss $\log K$ -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For equal-score loss $\log K$, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Compare probabilities summing to one with the nearest related construction in the lecture using a precise criterion such as risk, distance, curvature, impurity, or variance.
#
# <!-- Source: Multiclass Logistic Regression lecture; Precise comparison; probabilities summing to one -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For probabilities summing to one, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Express translation invariance of scores as an empirical-risk or objective-minimization statement with the summation over observations explicit.
#
# <!-- Source: Multiclass Logistic Regression lecture; ERM translation; translation invariance of scores -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For translation invariance of scores, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Design a compact diagnostic for detecting a problem with multiclass ERM using only quantities introduced in the lecture.
#
# <!-- Source: Multiclass Logistic Regression lecture; Diagnostic; multiclass ERM -->
#
# <details>
# <summary>Answer</summary>
#
# softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. For multiclass ERM, use the displayed identities and keep the lecture assumptions fixed.
#
# </details>

# %% [markdown]
# ### Question 19
#
# On a toy sample with two observations, compute the lecture quantity behind binary logistic as a special case; use symbols if the lecture did not give numbers.
#
# <!-- Source: Multiclass Logistic Regression lecture; Small computation; binary logistic as a special case -->
#
# <details>
# <summary>Answer</summary>
#
# On two observations, write the displayed objective with two summands and substitute the two inputs. softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. The calculation is complete once the requested loss, vote, projection, impurity, or variance term is evaluated from those summands.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Use the lecture geometry to describe numerical stability as a projection, partition, rotation, shrinkage, or local neighborhood. State the algebra behind the picture.
#
# <!-- Source: Multiclass Logistic Regression lecture; Geometric interpretation; numerical stability -->
#
# <details>
# <summary>Answer</summary>
#
# The geometric statement is the algebraic formula interpreted in the relevant space. softmax uses $p_{nk}=e^{x_n^Tw_k}/\sum_j e^{x_n^Tw_j}$ and loss $-\sum_k y_{nk}\log p_{nk}$. Only differences among class scores matter, which explains both argmax boundaries and the identifiability issue. This supplies both the picture and the calculation behind it.
#
# </details>
