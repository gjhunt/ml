# %% [markdown]
# # Multiclass Logistic Regression
#
# These review questions are based on the corresponding lecture notebook and include collapsible answers for self-study.

# %% [markdown]
# ### Question 1
#
# Write the lecture formula for linear class scores and identify how it enters the objective or prediction rule.
#
# <!-- Source: Multiclass Logistic Regression lecture; linear class scores -->
#
# <details>
# <summary>Answer</summary>
#
# The key calculation uses scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 2
#
# Derive the update or first-order condition for softmax probabilities, stating all assumptions.
#
# <!-- Source: Multiclass Logistic Regression lecture; softmax probabilities -->
#
# <details>
# <summary>Answer</summary>
#
# In the lecture notation, use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 3
#
# Test the lecture claim about one-hot labels: state the claim precisely and give the proof or necessary qualification.
#
# <!-- Source: Multiclass Logistic Regression lecture; one-hot labels -->
#
# <details>
# <summary>Answer</summary>
#
# The qualification uses scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 4
#
# Construct a concrete example showing what can go wrong with cross-entropy loss when the relevant lecture assumption is removed.
#
# <!-- Source: Multiclass Logistic Regression lecture; cross-entropy loss -->
#
# <details>
# <summary>Answer</summary>
#
# A minimal example is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 5
#
# Compare precisely log-sum-exp term with the adjacent lecture concept using a precise loss, risk, or algebraic criterion.
#
# <!-- Source: Multiclass Logistic Regression lecture; log-sum-exp term -->
#
# <details>
# <summary>Answer</summary>
#
# The criterion is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 6
#
# For a symbolic dataset with two or three observations, calculate the quantity used for matrix-form scores $XW$ and interpret the sign or magnitude.
#
# <!-- Source: Multiclass Logistic Regression lecture; matrix-form scores $XW$ -->
#
# <details>
# <summary>Answer</summary>
#
# For the symbolic calculation, use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 7
#
# Verify the dimensional or probabilistic constraints that make gradient $X^T(P-Y)$ well-defined.
#
# <!-- Source: Multiclass Logistic Regression lecture; gradient $X^T(P-Y)$ -->
#
# <details>
# <summary>Answer</summary>
#
# Well-definedness follows because use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 8
#
# Rewrite the lecture expression for identifiability in matrix notation and name each term.
#
# <!-- Source: Multiclass Logistic Regression lecture; identifiability -->
#
# <details>
# <summary>Answer</summary>
#
# Matrix notation gives use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 9
#
# Decide whether the standard statement about reference-class constraints; justify the decision with a formula.
#
# <!-- Source: Multiclass Logistic Regression lecture; reference-class constraints -->
#
# <details>
# <summary>Answer</summary>
#
# The statement is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 10
#
# Find the limiting behavior of the lecture formula for argmax decision rules under the relevant tuning parameter.
#
# <!-- Source: Multiclass Logistic Regression lecture; argmax decision rules -->
#
# <details>
# <summary>Answer</summary>
#
# The limiting case is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 11
#
# Give a counterexample demonstrating a limitation of pairwise decision boundaries in the lecture's model class.
#
# <!-- Source: Multiclass Logistic Regression lecture; pairwise decision boundaries -->
#
# <details>
# <summary>Answer</summary>
#
# A counterexample is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 12
#
# Translate precisely feature engineering into an empirical-risk statement with the summation over training observations explicit.
#
# <!-- Source: Multiclass Logistic Regression lecture; feature engineering -->
#
# <details>
# <summary>Answer</summary>
#
# The empirical-risk form is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 13
#
# Use the lecture geometric picture to characterize MNIST linear classifiers as a projection, partition, or transformation.
#
# <!-- Source: Multiclass Logistic Regression lecture; MNIST linear classifiers -->
#
# <details>
# <summary>Answer</summary>
#
# Geometrically, use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 14
#
# State the optimization problem defining one-vs-rest comparison and derive the quantity minimized at one algorithmic step.
#
# <!-- Source: Multiclass Logistic Regression lecture; one-vs-rest comparison -->
#
# <details>
# <summary>Answer</summary>
#
# The one-step objective is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 15
#
# List the assumptions needed for the theorem or identity involving equal-score loss $\log K$; which one fails in the common edge case?
#
# <!-- Source: Multiclass Logistic Regression lecture; equal-score loss $\log K$ -->
#
# <details>
# <summary>Answer</summary>
#
# The needed assumption is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 16
#
# Calculate how probabilities summing to one changes when one feature is rescaled or one observation is perturbed.
#
# <!-- Source: Multiclass Logistic Regression lecture; probabilities summing to one -->
#
# <details>
# <summary>Answer</summary>
#
# Under rescaling or perturbation, use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 17
#
# Give the precise decision rule or prediction rule connected with translation invariance of scores and resolve ties if needed.
#
# <!-- Source: Multiclass Logistic Regression lecture; translation invariance of scores -->
#
# <details>
# <summary>Answer</summary>
#
# The prediction rule is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 18
#
# Prove the monotonicity, convexity, or non-increase property used by the lecture for multiclass ERM.
#
# <!-- Source: Multiclass Logistic Regression lecture; multiclass ERM -->
#
# <details>
# <summary>Answer</summary>
#
# The property follows since use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 19
#
# Formulate a compact mathematical diagnostic for binary logistic as a special case using validation, residuals, variance, or impurity as appropriate.
#
# <!-- Source: Multiclass Logistic Regression lecture; binary logistic as a special case -->
#
# <details>
# <summary>Answer</summary>
#
# A diagnostic is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>

# %% [markdown]
# ### Question 20
#
# Summarize numerical stability by giving one formula and one mathematical reason it helps or fails in the lecture example.
#
# <!-- Source: Multiclass Logistic Regression lecture; numerical stability -->
#
# <details>
# <summary>Answer</summary>
#
# A compact summary is use scores $S=XW$, probabilities $p_{nk}=e^{s_{nk}}/\sum_j e^{s_{nj}}$, and cross-entropy $-\sum_k y_{nk}\log p_{nk}$. Identifiability is up to common score shifts.
#
# </details>
